# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Aircraft_Annotation_DataFile.csv')
df.head()
# Out:
#     IDENT                                            PROBLEM  \
# 0  100001                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 1  100002                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 2  100003                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 3  100004  HAD ENGINE CHOKE & BRIEFLY LOSE POWER ON DEPAR...
# 4  100005       #2 & 4 CYL ROCKER COVER GASKETS ARE LEAKING.
#
#                                               ACTION
# 0  TRIED TO ADJUST IDLE SEVERAL TIMES, WOULDN'T A...
# 1                      REMOVED & REPLACED FUEL SERVO
# 2  A/C WAS RUN UP, SET IDLE SPEED, MIXTURE OK, NO...
# 3  PERFORMED ENGINE RUN UP, FOUND CYL 2 LOWER PLU...
# 4                        REMOVED & REPLACED GASKETS.

# %%
df.shape
# Out:
# (6169, 3)

# %%
df.isna().sum()
# Out:
# IDENT      0
# PROBLEM    0
# ACTION     0
# dtype: int64

# %% [markdown]
# # Finding Unique problems

# %%
df['PROBLEM'].value_counts().head(10)
# Out:
# PROBLEM
# #2 INTAKE GASKET LEAKING.          82
# #2 INTAKE LEAKING.                 79
# #4 INTAKE LEAKING.                 70
# #4 INTAKE GASKET LEAKING.          62
# #2 INTAKE IS LEAKING.              45
# #3 INTAKE LEAKING.                 39
# #2 ROCKER COVER LEAKING.           38
# #2 ROCKER COVER GASKET LEAKING.    36
# #4 ROCKER COVER GASKET LEAKING.    34
# #3 INTAKE GASKET LEAKING.          34
# Name: count, dtype: int64

# %%
problem_counts = df['PROBLEM'].value_counts().reset_index()
# Renaming  the columns for clarity
problem_counts.columns = ['Problem', 'Count']
# Sorting
sorted_problem_counts = problem_counts.sort_values(by='Problem')

sorted_problem_counts.head(10)
# Out:
#                                                 Problem  Count
# 1651                    #1 & 2 CYL INTAKE GASKETS LEAK.      1
# 1998                 #1 & 2 CYL INTAKE GASKETS LEAKING.      1
# 3075           #1 & 2 CYL ROCKER COVER GASKETS LEAKING.      1
# 141                      #1 & 2 INTAKE GASKETS LEAKING.      5
# 698               #1 & 2 INTAKES LEAKING ON L/H ENGINE.      2
# 2099              #1 & 2 INTAKES LEAKING ON R/H ENGINE.      1
# 197                             #1 & 2 INTAKES LEAKING.      4
# 1169  #1 & 2 ROCKER COVER GASKETS LEAKING ON L/H ENG...      1
# 131                #1 & 2 ROCKER COVER GASKETS LEAKING.      5
# 520         #1 & 2 ROCKER COVERS LEAKING ON L/H ENGINE.      2

# %% [markdown]
# from here we can observe that there are many similar problems with different words
# eg, [rocket gaskets are leaking, rocket gaskets leaking], [Intake gaskets leak, Intake gaskets Leaking]

# %% [markdown]
# we have 3595 unique problems.
# 2 and 4 numbers mean something so we cannot remove them.
# also there are many similar/duplicate rows eg. (Intake leaking and Intake is leaking)

# %%
duplicate = df[df.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [IDENT, PROBLEM, ACTION]
# Index: []

# %% [markdown]
# Problem:
# For data cleaning and processing, we need to remove punctuation and special characters.
# but for eg. #2 & 4 Intakes leaking. if we remove # and & from this sentence, it might become difficult to analyze.
# also, we cannot remove numbers because they probably mean something. (the nth cylinder, engine etc.)

# %% [markdown]
# I can remove the full stop, convert each word to their lemma form, remove the stopwords such as 'is', 'are' etc.

# %% [markdown]
# # Text Preprocessing

# %%
import re
stopwords = ['ARE', 'IS'] # can also add 'was'
def remove_specific_stopwords(text, stopwords):

    # Remove punctuation (keeping /)
    text = re.sub(r'[^a-zA-Z0-9\s/]', '', text)

    # Tokenize the text
    tokens = text.split()

    # Remove specific stopwords
    filtered_tokens = [word for word in tokens if word not in stopwords]
    return filtered_tokens

# %%
df['processed_problem'] = df['PROBLEM'].apply(lambda x: remove_specific_stopwords(x, stopwords))

#similarly apply for actions as well
df['processed_action'] = df['ACTION'].apply(lambda x: remove_specific_stopwords(x, stopwords))
df.head(10)
# Out:
#     IDENT                                            PROBLEM  \
# 0  100001                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 1  100002                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 2  100003                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 3  100004  HAD ENGINE CHOKE & BRIEFLY LOSE POWER ON DEPAR...
# 4  100005       #2 & 4 CYL ROCKER COVER GASKETS ARE LEAKING.
# 5  100006           ROCKER BOX COVER SCREWS LOOSE (ALL CYL).
# 6  100007        INDUCTION TUBE HOSE CLAMPS LOOSE (ALL CYL).
# 7  100008                              #3 INTAKE IS LEAKING.
# 8  100009                              #2 INTAKE IS LEAKING.
# 9  100010                        #4 ROCKER COVER IS LEAKING.
#
#                                               ACTION  \
# 0  TRIED TO ADJUST IDLE SEVERAL TIMES, WOULDN'T A...
# 1                      REMOVED & REPLACED FUEL SERVO
# 2  A/C WAS RUN UP, SET IDLE SPEED, MIXTURE OK, NO...
# 3  PERFORMED ENGINE RUN UP, FOUND CYL 2 LOWER PLU...
# 4                        REMOVED & REPLACED GASKETS.
# 5                                  TIGHTENED SCREWS.
# 6                             TIGHTENED HOSE CLAMPS.
# 7                         REMOVED & REPLACED GASKET.
# 8               REMOVED & REPLACED #2 INTAKE GASKET.
# 9         REMOVED & REPLACED #4 ROCKER COVER GASKET.
#
#                                    processed_problem  \
# 0           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 1           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 2           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 3  [HAD, ENGINE, CHOKE, BRIEFLY, LOSE, POWER, ON,...
# 4       [2, 4, CYL, ROCKER, COVER, GASKETS, LEAKING]
# 5      [ROCKER, BOX, COVER, SCREWS, LOOSE, ALL, CYL]
# 6   [INDUCTION, TUBE, HOSE, CLAMPS, LOOSE, ALL, CYL]
# 7                               [3, INTAKE, LEAKING]
# 8                               [2, INTAKE, LEAKING]
# 9                        [4, ROCKER, COVER, LEAKING]
#
#                                     processed_action
# 0  [TRIED, TO, ADJUST, IDLE, SEVERAL, TIMES, WOUL...
# 1                   [REMOVED, REPLACED, FUEL, SERVO]
# 2  [A/C, WAS, RUN, UP, SET, IDLE, SPEED, MIXTURE,...
# 3  [PERFORMED, ENGINE, RUN, UP, FOUND, CYL, 2, LO...
# 4                       [REMOVED, REPLACED, GASKETS]
# 5                                [TIGHTENED, SCREWS]
# 6                          [TIGHTENED, HOSE, CLAMPS]
# 7                        [REMOVED, REPLACED, GASKET]
# 8             [REMOVED, REPLACED, 2, INTAKE, GASKET]
# 9      [REMOVED, REPLACED, 4, ROCKER, COVER, GASKET]

# %% [markdown]
# ## Handling Abbreviations

# %%
abbreviations_df = pd.read_csv('Aviation_Abbreviation_Dataset.csv')

abbreviations_df['Abbreviated'] = abbreviations_df['Abbreviated'].apply(lambda x: x.upper())
abbreviations_df['Standard_Description'] = abbreviations_df['Standard_Description'].apply(lambda x: x.upper())

# %%
abbreviations_df.head(10)
# Out:
#    Abbriviation_Code Abbreviated Standard_Description
# 0               1001         AGL   ABOVE GROUND LEVEL
# 1               1002          AF    AIRWAY FACILITIES
# 2               1003         ALM                ALARM
# 3               1004         ALT           ALTERNATOR
# 4               1005        APCH             APPROACH
# 5               1006        ASSY             ASSEMBLY
# 6               1007        ASST            ASSISTANT
# 7               1008        BATT              BATTERY
# 8               1009          CO      CARBON MONOXIDE
# 9               1010        CARB           CARBURETOR

# %%
# Create a dictionary from the abbreviation DataFrame
abbr_dict = dict(zip(abbreviations_df['Abbreviated'], abbreviations_df['Standard_Description']))
abbr_dict['CYLS'] = 'CYLINDERS'

# Function to replace abbreviations in a list of words
def replace_abbr(words):
    return [abbr_dict.get(word, word) for word in words]

df['processed_problem'] = df['processed_problem'].apply(replace_abbr)
df['processed_action'] = df['processed_action'].apply(replace_abbr)

# %%
df.head(10)
# Out:
#     IDENT                                            PROBLEM  \
# 0  100001                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 1  100002                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 2  100003                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 3  100004  HAD ENGINE CHOKE & BRIEFLY LOSE POWER ON DEPAR...
# 4  100005       #2 & 4 CYL ROCKER COVER GASKETS ARE LEAKING.
# 5  100006           ROCKER BOX COVER SCREWS LOOSE (ALL CYL).
# 6  100007        INDUCTION TUBE HOSE CLAMPS LOOSE (ALL CYL).
# 7  100008                              #3 INTAKE IS LEAKING.
# 8  100009                              #2 INTAKE IS LEAKING.
# 9  100010                        #4 ROCKER COVER IS LEAKING.
#
#                                               ACTION  \
# 0  TRIED TO ADJUST IDLE SEVERAL TIMES, WOULDN'T A...
# 1                      REMOVED & REPLACED FUEL SERVO
# 2  A/C WAS RUN UP, SET IDLE SPEED, MIXTURE OK, NO...
# 3  PERFORMED ENGINE RUN UP, FOUND CYL 2 LOWER PLU...
# 4                        REMOVED & REPLACED GASKETS.
# 5                                  TIGHTENED SCREWS.
# 6                             TIGHTENED HOSE CLAMPS.
# 7                         REMOVED & REPLACED GASKET.
# 8               REMOVED & REPLACED #2 INTAKE GASKET.
# 9         REMOVED & REPLACED #4 ROCKER COVER GASKET.
#
#                                    processed_problem  \
# 0           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 1           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 2           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 3  [HAD, ENGINE, CHOKE, BRIEFLY, LOSE, POWER, ON,...
# 4  [2, 4, CYLINDER, ROCKER, COVER, GASKETS, LEAKING]
# 5  [ROCKER, BOX, COVER, SCREWS, LOOSE, ALL, CYLIN...
# 6  [INDUCTION, TUBE, HOSE, CLAMPS, LOOSE, ALL, CY...
# 7                               [3, INTAKE, LEAKING]
# 8                               [2, INTAKE, LEAKING]
# 9                        [4, ROCKER, COVER, LEAKING]
#
#                                     processed_action
# 0  [TRIED, TO, ADJUST, IDLE, SEVERAL, TIMES, WOUL...
# 1                   [REMOVED, REPLACED, FUEL, SERVO]
# 2  [A/C, WAS, RUN, UP, SET, IDLE, SPEED, MIXTURE,...
# 3  [PERFORMED, ENGINE, RUN, UP, FOUND, CYLINDER, ...
# 4                       [REMOVED, REPLACED, GASKETS]
# 5                                [TIGHTENED, SCREWS]
# 6                          [TIGHTENED, HOSE, CLAMPS]
# 7                        [REMOVED, REPLACED, GASKET]
# 8             [REMOVED, REPLACED, 2, INTAKE, GASKET]
# 9      [REMOVED, REPLACED, 4, ROCKER, COVER, GASKET]

# %%
processed_df = pd.DataFrame([df['processed_problem'], df['processed_action']])
processed_df = processed_df.transpose()
processed_df.head(10)
# Out:
#                                    processed_problem  \
# 0           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 1           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 2           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 3  [HAD, ENGINE, CHOKE, BRIEFLY, LOSE, POWER, ON,...
# 4  [2, 4, CYLINDER, ROCKER, COVER, GASKETS, LEAKING]
# 5  [ROCKER, BOX, COVER, SCREWS, LOOSE, ALL, CYLIN...
# 6  [INDUCTION, TUBE, HOSE, CLAMPS, LOOSE, ALL, CY...
# 7                               [3, INTAKE, LEAKING]
# 8                               [2, INTAKE, LEAKING]
# 9                        [4, ROCKER, COVER, LEAKING]
#
#                                     processed_action
# 0  [TRIED, TO, ADJUST, IDLE, SEVERAL, TIMES, WOUL...
# 1                   [REMOVED, REPLACED, FUEL, SERVO]
# 2  [A/C, WAS, RUN, UP, SET, IDLE, SPEED, MIXTURE,...
# 3  [PERFORMED, ENGINE, RUN, UP, FOUND, CYLINDER, ...
# 4                       [REMOVED, REPLACED, GASKETS]
# 5                                [TIGHTENED, SCREWS]
# 6                          [TIGHTENED, HOSE, CLAMPS]
# 7                        [REMOVED, REPLACED, GASKET]
# 8             [REMOVED, REPLACED, 2, INTAKE, GASKET]
# 9      [REMOVED, REPLACED, 4, ROCKER, COVER, GASKET]

# %% [markdown]
# # Lemmatisation
#
#
#
# ---

# %%
import pandas as pd
import spacy

# Load the spaCy model for English
nlp = spacy.load('en_core_web_sm')

# Function to lemmatize a list of tokens
def lemmatize_tokens(tokens):
    doc = nlp(" ".join(tokens))
    return [token.lemma_ for token in doc]

# Apply lemmatization to each row in the 'tokens' column
processed_df['lemmatized_problems'] = processed_df['processed_problem'].apply(lemmatize_tokens)

processed_df.head(10)
# Out:
#                                    processed_problem  \
# 0           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 1           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 2           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 3  [HAD, ENGINE, CHOKE, BRIEFLY, LOSE, POWER, ON,...
# 4  [2, 4, CYLINDER, ROCKER, COVER, GASKETS, LEAKING]
# 5  [ROCKER, BOX, COVER, SCREWS, LOOSE, ALL, CYLIN...
# 6  [INDUCTION, TUBE, HOSE, CLAMPS, LOOSE, ALL, CY...
# 7                               [3, INTAKE, LEAKING]
# 8                               [2, INTAKE, LEAKING]
# 9                        [4, ROCKER, COVER, LEAKING]
#
#                                     processed_action  \
# 0  [TRIED, TO, ADJUST, IDLE, SEVERAL, TIMES, WOUL...
# 1                   [REMOVED, REPLACED, FUEL, SERVO]
# 2  [A/C, WAS, RUN, UP, SET, IDLE, SPEED, MIXTURE,...
# 3  [PERFORMED, ENGINE, RUN, UP, FOUND, CYLINDER, ...
# 4                       [REMOVED, REPLACED, GASKETS]
# 5                                [TIGHTENED, SCREWS]
# 6                          [TIGHTENED, HOSE, CLAMPS]
# 7                        [REMOVED, REPLACED, GASKET]
# 8             [REMOVED, REPLACED, 2, INTAKE, GASKET]
# 9      [REMOVED, REPLACED, 4, ROCKER, COVER, GASKET]
#
#                                  lemmatized_problems
# 0             [engine, IDLE, OVERRIDE, kill, engine]
# 1             [engine, IDLE, OVERRIDE, kill, engine]
# 2             [engine, IDLE, OVERRIDE, kill, engine]
# 3  [have, ENGINE, CHOKE, BRIEFLY, LOSE, POWER, ON...
# 4  [2, 4, cylinder, ROCKER, COVER, GASKETS, leaking]
# 5  [ROCKER, BOX, COVER, SCREWS, LOOSE, all, cylin...
# 6  [INDUCTION, TUBE, HOSE, CLAMPS, LOOSE, all, cy...
# 7                               [3, intake, leaking]
# 8                               [2, INTAKE, leaking]
# 9                        [4, rocker, COVER, leaking]

# %%
for row in df['processed_problem']:
    if 'LEAK' in row:
        print(row)
# each row with leak word can be replaced by leaking.
# Out:
# ['R/H', 'ENGINE', '3', '2', 'INTAKES', 'LEAK']
# ['2', '3', '4', 'ROCKER', 'COVERS', 'LEAK']
# ['OIL', 'LEAK', 'EVIDENCE', 'ON', 'R/H', 'SIDE', 'OF', 'ENGINE']
# ['OIL', 'LEAK', 'EVIDENCE', 'ON', 'R/H', 'SIDE', 'OF', 'ENGINE']
# ['OIL', 'LEAK', 'FROM', 'L/H', 'ENGINE']
# ['OIL', 'LEAK', 'FROM', 'L/H', 'ENGINE']
# ['OIL', 'LEAK', 'NOTED', 'ON', 'FRONT', 'ENGINE', 'SECTION']
# ['OIL', 'LEAK', 'NOTED', 'ON', 'FRONT', 'ENGINE', 'SECTION']
# ['CYLINDER', '2', 'INTAKE', 'TUBE', 'AT', 'SUMP', 'HAS', 'POSSIBLE', 'FUEL', 'LEAK']
# ['LEAKING', 'INTAKE', 'TUBE', 'CYLINDER', '4', 'LEAK', 'AT', 'ATTACH', 'POINT', 'TO', 'OIL', 'SUMP']
# ['LEAKING', 'INTAKE', 'TUBE', 'CYLINDER', '4', 'LEAK', 'AT', 'ATTACH', 'POINT', 'TO', 'OIL', 'SUMP']
# ['OIL', 'LEAK', 'ON', 'R/H', 'ENGINE', 'BACK', 'BONE', 'CASE', 'SEAM']
# ['OIL', 'LEAK', 'ON', 'R/H', 'ENGINE', 'BACK', 'BONE', 'CASE', 'SEAM']
# ['3', '2', 'ROCKER', 'COVER', 'GASKETS', 'LEAK', 'R/H', 'ENGINE']
# ['3', '2', 'ROCKER', 'COVER', 'GASKETS', 'LEAK', 'L/H', 'ENGINE']
# ['4', 'ROCKER', 'COVER', 'GASKET', 'LEAKING', '2', 'ROCKER', 'COVER', 'GASKET', 'LEAK']
# ['R/H', 'ENGINE', 'OIL', 'LEAK', 'AT', 'FILTER', 'HOUSING', 'AFTER', 'RUN', 'UP']
# ['2', 'INTAKE', 'HAS', 'LEAK']
# ['ROUGH', 'ENGINE', 'W/', 'OIL', 'LEAK']
# ['ROUGH', 'ENGINE', 'W/', 'OIL', 'LEAK']
# ['ROUGH', 'ENGINE', 'W/', 'OIL', 'LEAK']
# ['ROUGH', 'ENGINE', 'W/', 'OIL', 'LEAK']
# ['ROUGH', 'ENGINE', 'W/', 'OIL', 'LEAK']
# ['OIL', 'LEAK', 'AT', 'CRANKCASE', 'BOLTS', 'USED', 'TO', 'MOUNT', 'FUEL', 'FLOW', 'TRANSDU']
# ['3', '4', 'ROCKER', 'COVERS', 'LEAK']
# ['R/H', 'ENGINE', 'HAS', 'OIL', 'LEAK', 'AT', 'HOISTING', 'LOOP']
# ['R/H', 'ENGINE', 'HAS', 'OIL', 'LEAK', 'AT', 'HOISTING', 'LOOP']
# ['SIMULATED', 'OIL', 'LEAK', 'ON', 'ENGINE']
# ['2', 'INTAKE', 'SLIGHT', 'LEAK']
# ['R/H', 'ENGINE', '2', '4', 'INTAKE', 'HAVE', 'SLIGHT', 'LEAK']
# ['TOP', 'BOLT', 'ON', 'CRANKCASE', 'HAS', 'OIL', 'LEAK']
# ['OIL', 'LEAK', 'AT', 'FRONT', 'LOWER', 'PORTION', 'OF', 'CRANKCASE', 'NEAR', 'OIL', 'SEAL']
# ['OIL', 'LEAK', 'AT', 'FRONT', 'LOWER', 'PORTION', 'OF', 'CRANKCASE', 'NEAR', 'OIL', 'SEAL']
# ['R/H', 'ENGINE', '2', 'CYLINDER', 'COMPRESSION', '15/80', 'EXHAUST', 'LEAK']
# ['R/H', 'ENGINE', '2', 'CYLINDER', 'COMPRESSION', '15/80', 'EXHAUST', 'LEAK']
# ['SMALL', 'LEAK', 'NOTED', 'ON', 'UPPER', 'ENGINE', 'CRANKCASE', 'BACKBONE']
# ['LEAK', 'NOTED', 'BY', 'OIL', 'RETURN', 'LINE', 'BYT', 'ACCESSORY', 'CASE']
# ['VACUUM', 'PUMP', 'HAS', 'POSSIBLE', 'OIL', 'LEAK']
# ['VACUUM', 'PUMP', 'HAS', 'POSSIBLE', 'OIL', 'LEAK']
# ['1', '3', 'CYLINDER', 'ROCKER', 'COVERS', 'LEAK']
# ['1', '3', 'CYLINDER', 'ROCKER', 'COVERS', 'LEAK']
# ['1', '3', '4', 'INTAKES', 'LEAK']
# ['R/H', 'ENGINE', '4', '3', 'INTAKE', 'GASKETS', 'LEAK']
# ['R/H', 'ENGINE', '4', '3', 'INTAKE', 'GASKETS', 'LEAK']
# ['R/H', 'ENGINE', '2', '4', 'INTAKE', 'TUBE', 'GASKETS', 'LEAK']
# ['R/H', 'ENGINE', 'HAS', 'OIL', 'LEAK', 'ON', 'LIFT', 'BOLT']
# ['EVIDENCE', 'OF', 'OIL', 'LEAK', 'ON', 'PILOT', 'SIDE', 'OF', 'ENGINE']
# ['A/C', 'BEGAN', 'TO', 'LEAK', 'LARGE', 'QUANTITIES', 'OF', 'OIL', 'OUT', 'OF', 'RIGHT', 'COWLI']
# ['1', '3', 'INTAKES', 'LEAK']
# ['MAINTENANCE', 'FLIGHT', 'REQUIRED', 'FOR', 'M/R', 'LEAK']
# ['MAINTENANCE', 'FLIGHT', 'REQUIRED', 'FOR', 'M/R', 'LEAK']
# ['4', 'INTAKE', 'OIL', 'LEAK']
# ['1', '3', 'ROCKER', 'COVER', 'GASKETS', 'LEAK']
# ['OIL', 'LEAK', 'DISCOVERED', 'ON', '2', 'CYLINDER']
# ['OIL', 'LEAK', 'ON', 'RIGHT', 'FORWARD', 'CYLINDER', 'INTAKE', 'TUBE']
# ['4', 'CYLINDER', 'INTAKE', 'LEAK']
# ['L/H', 'ENGINE', '2', '4', 'INTAKE', 'GASKETS', 'LEAK']
# ['OIL', 'LEAK', 'ABOVE', 'L/H', 'MAGNETOS']
# ['OIL', 'LEAK', 'ABOVE', 'L/H', 'MAGNETOS']
# ['ALL', 'ROCKER', 'COVER', 'GASKETS', 'LEAK']
# ['1', '2', 'CYLINDER', 'INTAKE', 'GASKETS', 'LEAK']
# ['2', '3', 'ROCKER', 'COVER', 'GASKETS', 'LEAK']
# ['R/H', 'ENGINE', 'HAS', 'LEAK', 'ALONG', 'BACK', 'BONE']
# ['2', 'INTAKE', 'LEAK', 'L/H', 'ENGINE']
# ['3', 'INTAKE', 'LEAK', 'R/H', 'ENGINE']
# ['OIL', 'LEAK', 'AT', 'R/H', 'ENGINE', 'BACK', 'BONE', 'AFT', 'BOLT']
# ['FUEL', 'LEAK', 'FROM', 'DRAIN']
# ['OIL', 'LEAK', 'AT', 'L/H', 'ENGINE', 'HOISTING', 'LOOP']
# ['OIL', 'LEAK', 'AT', 'L/H', 'ENGINE', 'HOISTING', 'LOOP']
# ['SMALL', 'LEAK', 'ON', 'R/H', 'ENGINE', 'BACK', 'BONE']
# ['SMALL', 'LEAK', 'ON', 'R/H', 'ENGINE', 'BACK', 'BONE']
# ['PILOT', 'REPORTED', 'INTAKE', 'LEAK']
# ['CYLINDER', '2', 'SUSPECTED', 'OIL', 'LEAK', 'AT', 'BASE']
# ['CYLINDER', '2', 'SUSPECTED', 'OIL', 'LEAK', 'AT', 'BASE']
# ['INTAKE', 'GASKETS', '3', '4', 'CYLINDER', 'LEAK']
# ['3', '4', 'CYLINDER', 'ROCKER', 'COVER', 'GASKETS', 'LEAK']

# %% [markdown]
# # Converting tokenised words back to sentence.

# %%
problem_list = df['processed_problem'].tolist()
count = 0

for index, sentence in enumerate(problem_list):
    count += 1
    complete_sentence = ""
    for word in sentence:
        # Ensure that word is a string
        if isinstance(word, list):
            word = ' '.join(map(str, word))  # Flatten list to a single string
        complete_sentence += str(word) + " "
    print(complete_sentence.strip())

    problem_list[index] = complete_sentence.strip()

print(count)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2 4 BAFFLE OUTER TIE SPRING BROKEN
# 2 4 BAFFLE INNER TIE SPRING OUT OF PLACE
# 2 ROCKER COVER LEAKING
# OIL LEAK FROM L/H ENGINE
# OIL LEAK FROM L/H ENGINE
# 2 ROCKER COVER LEAKING ON L/H ENGINE
# 2 ROCKER COVER LEAKING ON R/H ENGINE
# 2 ROCKER COVER THRUST BUTTON ON R/H ENGINE BROKEN
# 2 ROCKER COVER THRUST BUTTONS ON L/H ENGINE BROKEN
# CYLINDER 3 BAFFLE SCREW SECURED TO CRANKCASE MISSING
# ROCKER COVER GASKET CYLINDER 3 LEAKING
# BAFFLE SUPPORT ON AFT COPILOT SIDE ENGINE BAFFLE LOOSE
# AFTER COMPLETING STEEP SPIRALS AT POWER IDLE SMOOTHLY APPLI
# AFTER COMPLETING STEEP SPIRALS AT POWER IDLE SMOOTHLY APPLI
# R/H ENGINE 3 CYLINDER LOOSE BAFFLE RUBBING ON OIL RETURN LINE CY
# CYLINDER 2 INTAKE LEAKING
# R/H ENGINE 3 INTAKE LEAKING
# R/H ENGINE L/H FORWARD BAFFLE SEAL GONE
# L/H SIDE BAFFLE CRACKED
# PLUGS FOR ENGINE BAFFLING WORN
# 3 4 ROCKER COVERS LEAKING
# R/H ENGINE 2 BAFFLE MISSING A BOLT
# R/H 4 AFT BAFFLE CRACKED
# ROCKER BOX COVER SCREWS LOOSE
# SIDE BAFFLE PLUGS HAVE MANY MISSING FINGERS
# 2 ROCKER COVER LEAKING
# BAFFLE SCREW BEHIND DIPSTICK LOOSE
# 2 4 CYLINDER ROCKER COVER GASKETS LEAKING ON R/H ENGINE
# 2 ROCKER COVER LEAKING
# L/H ENGINE BAFFLE SEAL ABOVE 4 CYLINDER TORN
# ROCKER COVER GASKET CYLINDER 2 R/H ENGINE LEAKING
# INTAKE GASKET CYLINDER 3 R/H ENGINE LEAKING
# CYLINDER 3 4 ROCKER COVER GASKETS LEAKING ON L/H ENGINE
# CYLINDER 3 AFT UPPER BAFFLE SEAL LOOSE
# BOTH BAFFLE PLUGS MISSING TOO MANY TABS
# 4 INTAKE GASKET LEAKING
# 4 ROCKER COVER GASKET LEAKING
# SIDE BAFFLE PLUGS MISSING FINGERS
# 2 4 ROCKER COVER GASKETS LEAKING
# L/H 1 2 3 ROCKER GASKETS LEAKING
# L/H 4 INTAKE GASKET LEAKING
# L/H 3 CYLINDER ROCKER SHAFT THRUST BUTTONS DETERIORATED
# R/H ENGINE R/H REAR ENGINE BAFFLE SEAL LOOSE
# 4 INTAKE LEAKING
# 3 ROCKER COVER LEAKING
# 2 4 ROCKER COVER LEAKING
# RIVETS MISSING ON ENGINE DATA PLATE
# 3 4 INTAKES LEAKING ON L/H ENGINE
# 2 3 INTAKES LEAKING ON R/H ENGINE
# 2 ROCKER COVER LEAKING ON R/H ENGINE
# 2 3 4 ROCKER COVERS LEAKING ON L/H ENGINE
# ROCKER COVER GASKET CYLINDER 2 LEAKING
# 2 4 ROCKER COVERS LEAKING ON R/H ENGINE
# CRACK ON ENGINE BAFFLE LEFT SIDE BY 3 CYLINDER
# CRACK ON ENGINE BAFFLE LEFT SIDE BY 3 CYLINDER
# L/H BAFFLE SEAL REQUIRES REPLACEMENT
# R/H ENGINE 4 ROCKER COVER LEAKS
# R/H ENGINE 1 4 INTAKES LEAKING
# L/H ENGINE CYLINDER 3 ROCKER GASKET LEAKING
# R/H ENGINE 2 3 ROCKER COVERS LEAKING
# R/H ENGINE 4 CYLINDER HAS LOW COMPRESSION 20/80 PSI
# R/H ENGINE 4 CYLINDER HAS LOW COMPRESSION 20/80 PSI
# R/H 3 AFT BAFFLE SEAL LOOSE
# L/H 2 INTAKE GASKET LEAKING
# L/H ENGINE O/B BAFFLE TIE ROD BROKEN
# 4 INTAKE GASKET LEAKING R/H ENGINE
# R/H 2 SIDE BAFFLE SEAL LOOSE
# 2 4 INTAKES LEAKING
# ENGINE BAFFLE CYLINDER 3 MOUNT BRACKET SHEARED RIVET
# L/H BAFFLE PLUG HOLE TOO LARGE
# 3 4 INTAKE LEAKING
# 2 3 4 ROCKER COVERS LEAKING
# RIVET SHEARED R/H AFT BAFFLE
# R/H ENGINE OIL RETURN LINES LEAKING
# R/H ENGINE OIL RETURN LINES LEAKING
# R/H ENGINE 3 INTAKE LEAKING
# L/H ENGINE 4 INTAKE LEAKING
# L/H ENGINE 3 ROCKER COVER LEAKING
# R/H ENGINE 2 3 ROCKER COVERS LEAKING
# 3 ROCKER COVER LEAKING
# 3 INTAKE LEAKING
# CYLINDER 1 ROCKER COVER GASKET LEAKING
# L/H BUTTON PLUG WORN
# WHILE TAXING ENGINE COUGHED SPUTTERED ANYTIME RPMS WERE B
# WHILE TAXING ENGINE COUGHED SPUTTERED ANYTIME RPMS WERE B
# CYLINDER 2 INTAKE PIPE GASKET LEAKING
# 2 CYLINDER ROCKER COVER GASKET LEAKING
# R/H ENGINE OIL COOLER BAFFLE CRACKED
# ROCKER COVER GASKET CYLINDER 2 3 LEAKING
# INTERCYLINDER BAFFLE SUPPORT ROD BROKEN
# R/H ENGINE OIL RETURN LIKE CLAMPS LOOSE
# R/H ENGINE BAFFLE CRACKED BY OIL COOLER
# L/H ENGINE CYLINDER 3 ROCKER COVER GASKET LEAKING
# CYLINDER 3 ROCKER COVER MISSING A SCREW
# 2 ROCKER COVER LEAKING
# CYLINDER 2 INTAKE LEAKING
# WIRING HOLDER BROKEN ON CYLINDER 1
# 3 ROCKER COVER GASKET LEAKING
# 4 INTAKE GASKET LEAKING
# 2 INDUCTION TUBE GASKET LEAKING
# HIDDEN DAMAGE INSP REQUIRED FOR ENGINE FIRE
# 2 INTAKE LEAKING
# CYLINDER 3 ROCKER COVER LEAKING
# 2 1 INTAKE R/H ENGINE LEAKING
# 2 ROCKER COVER LEAKING
# L/H ENGINE INTAKE GASKET CYLINDER 2 LEAKING
# L/H ENGINE CYLINDER 1 2 3 ROCKER COVER GASKETS LEAKING
# 2 ROCKER COVER LEAKING
# 2 ROCKER COVER LEAKING
# 4 ROCKER COVER LEAKING
# 6 COWL SHOCK MOUNT TORN
# 2 INTAKE LEAKING ON L/H ENGINE
# 3 ROCKER COVER LEAKING ON L/H ENGINE
# ROCKER COVERS 1 3 LEAKING ON R/H ENGINE
# ROCKER COVER GASKET 3 TORN
# L/H R/H ENGINE BAFFLE PLUGS DAMAGED
# L/H ENGINE 4 CYLINDER INTAKE GASKET LEAKING
# L/H ENGINE 3 CYLINDER ROCKER COVER GASKET LEAKING
# 3 INTAKE TUBE RUBBING ON BAFFLE
# 2 INTAKE TUBE LEAKS AT CYLINDER
# LOOSE ENGINE GROUND
# INTAKE GASKET CYLINDER 4 LEAKING
# ROCKER COVER GASKET CYLINDER 4 LEAKING
# BAFFLE SUPPORT STEEL ROD CYLINDER 2 4 MISSING
# INTAKE GASKETS CYLINDER 2 4 LEAKING
# ROCKER COVER GASKETS CYLINDER 2 4 LEAKING
# 3 CYLINDER AFT BAFFLE BRACKET LOOSE BRACKET SECURED TO ENGINE C
# R/H BAFFLE PLUG NEEDS TO BE REPLACED
# 3 ROCKER COVER GASKET TORN
# 2 ROCKER COVER LEAKING
# 3 INTAKE LEAKING
# 3 ROCKER COVER LEAKING
# ROCKER COVER GASKET 3 TORN
# SIDE BAFFLE PLUGS MISSING FINGERS
# L/H ENGINE 2 4 ROCKER COVERS LEAKING
# ROCKER COVER GASKETS CYLINDER 2 3 LEAKING
# INTAKE TUBE LEAKING AT CONNECTION POINT W/ OIL SUMP CYLINDER 4
# INTAKE TUBE LEAKING AT CONNECTION POINT W/ OIL SUMP CYLINDER 4
# UPPER R/H BAFFLE SEAL LOOSE
# R/H ENGINE RUNNING ROUGH ENGINE WAS FINE LOW ALTITUDES O
# CYLINDER 4 AFT BAFFLE CRACKED
# CYLINDER 4 2 ROCKER COVER GASKETS LEAKING
# INTAKE 2 LEAKING ON L/H ENGINE
# 2 ROCKER SHAFT THRUST PLUG BROKEN
# ROCKER COVERS 2 3 4 LEAKING ON L/H ENGINE
# LEFT REAR BAFFLE CRACKED ON R/H ENGINE
# 2 INTAKE GASKET LEAKING
# 3 ROCKER GASKET LEAKING
# L/H ENGINE CYLINDER 2 3 INTAKE GASKETS LEAKING
# L/H ENGINE CYLINDER 3 ROCKER COVER GASKET LEAKING
# R/H ENGINE CYLINDER 3 ROCKER COVER GASKET LEAKING
# 1 INTAKE GASKET LEAKING
# 3 ROCKER COVER GASKET LEAKING
# ROCKER COVER GASKET ON CYLINDER 2 LEAKING
# SHEARED RIVET ON CYLINDER 3 BAFFLE AFT
# 2 4 CYLINDER ROCKER COVER GASKETS LEAKING
# CYLINDER 3 INTAKE TUBE FLANGE LEAKING FUEL CONNECTION BETWEEN T
# 1 ROCKER COVER LEAKING
# TOP BAFFLE BACK SIDE RIVETS MISSING
# 1 CYLINDER STAND OFF BROKEN
# 2 3 ROCKER COVERS LEAKING
# FORWARD R/H SIDE ENGINE BAFFLE CRACKED
# CYLINDER 1 2 INTAKE GASKETS LEAKING
# INTAKE GASKET CYLINDER 4 LEAKING
# ROCKER COVER GASKET CYLINDER 2 LEAKING
# 3 INTAKE LEAKING ON L/H ENGINE
# BAFFLE CORNER BY CYLINDER 4 CRACKED
# CYLINDER 1 3 2 ROCKER COVER GASKETS LEAKING
# REAR ENGINE BAFFLE BRACKET LOOSE
# ENGINE OVERSPEED TO 3300 RPM
# R/H ENGINE BAFFLE SCREW MISSING
# A/C WOULDNT START
# 3 INTAKE LEAKING ON R/H ENGINE
# 2 INTAKE LEAKING
# 2 ROCKER COVER LEAKING
# R/H BACK BAFFLE RIVET HEAD SHEARED
# R/H BACK BAFFLE RIVET HEAD SHEARED
# R/H L/H ENGINE BAFFLE SEAL LOOSE
# 2 3 4 CYLINDER ROCKER COVER GASKETS LEAKING
# L/H 2 3 ROCKER GASKETS LEAKING
# R/H 2 4 ROCKER GASKETS LEAKING
# 2 ROCKER COVER GASKET LEAKING
# 3 ROCKER COVER GASKET LEAKING
# 3 ROCKER COVER LEAKING ON L/H ENGINE
# 2 INTAKE LEAKING ON L/H ENGINE
# R/H ENGINE 2 4 CYLINDER ROCKER COVER GASKETS LEAKING
# R/H ENGINE 1 3 INTAKE GASKETS LEAKING
# ALL 4 ROCKER GASKETS LEAKING
# 2 3 INTAKE GASKETS LEAKING
# 1 2 3 4 ROCKER COVER GASKETS LEAKING
# 3 ROCKER COVER LEAKING
# 2 3 INTAKES LEAKING ON L/H ENGINE
# R/H ENGINE 2 ROCKER COVER GASKET LEAKING
# 2 3 ROCKER COVERS LEAKING ON L/H ENGINE
# L/H CARBURETOR HEAT BRACKET LOOSE
# R/H 4 INTAKE GASKET LEAKING
# 3 ROCKER COVER LEAKING
# 1 ROCKER COVER GASKET LEAKING
# MIXTURE CHECK FAILS RPM 200 RISE
# 4 INTAKE GASKET LEAKING
# AFT BAFFLE BRACKET MISSING SCREW
# 3 4 INTAKE GASKETS LEAKING
# 2 INTAKE GASKET LEAKING
# L/H AFT BAFFLE CRACKED
# ROCKER COVER GASKETS CYLINDER 2 3 4 LEAKING
# R/H AFT BAFFLE SUPPORT RIVETS SHEARED
# TOP BAFFLE CRACKED
# L/H AFT BAFFLE CRACKED
# L/H SIDE BAFFLE CRACKED
# R/H SIDE BAFFLE CRACKED
# INDUCTION AIR FILTER CAN BE REPLACED
# BOTH LOWER DEFLECTORS CRACKED
# FORWARD L/H BAFFLE ANTICHAFE STRIP FELL OFF
# 3 INTAKE LEAKING
# R/H 3 AFT BAFFLE CRACKED
# L/H 3 INTAKE GASKET LEAKING
# R/H 2 4 INTAKE GASKETS LEAKING
# L/H ALL 4 ROCKER GASKETS LEAKING
# R/H ENGINE ALL 4 ROCKER GASKETS LEAKING
# ENGINE DIRTY
# 2 ROCKER COVER LEAKING
# 1 3 4 ROCKER COVERS LEAKING
# CYLINDER 2 1 ROCKER COVER GASKETS LEAKING
# ROCKER COVER GASKET FROM 3 CYLINDER TORN
# REAR R/H ENGINE BAFFLE BRACKET RIVETS SHEARED
# 3 INTAKE LEAKING
# R/H REAR ENGINE BAFFLE SCREW LOOSE
# ENGINE DIRTY
# 2 INTAKE LEAKING
# MISSING SCREW FRONT BAFFLE ON R/H SIDE
# 1 2 4 ROCKER COVERS LEAKING
# 3 INTAKE GASKET LEAKING
# 2 3 ROCKER GASKET LEAKING
# ROCKER COVER GASKET 3 CYLINDER LEAKING
# AFT ENGINE BAFFLE BY CYLINDER 3 SUPPORT SECURED TO ENGINE CASE
# 3 ROCKER COVER LEAKING ON L/H ENGINE
# 2 ROCKER COVER LEAKING ON R/H ENGINE
# CYLINDER 2 INTAKE GASKET LEAKING
# CYLINDER 1 ROCKER COVER GASKET LEAKING
# REAR R/H ENGINE BAFFLE BRACKET CRACKED
# R/H REAR ENGINE BAFFLE MOUNTING SCREW MISSING
# 2 4 ROCKER COVER LEAKING
# ENGINE DIRTY
# CYLINDER 1 FORWARD BAFFLE CRACKED
# 3 ROCKER COVER LEAKING
# STUDENT COULDNT START A/C
# ENGINE RUNNING ROUGH AT IDLE
# L/H ENGINE CYLINDER 3 AFT BAFFLE CRACKED
# R/H ENGINE 3 INTAKE TUBE LEAKING
# L/H ENGINE 2 3 4 ROCKER BOX COVERS LEAKING
# IMPELLER MAKING CONTACT W/ SCROLL
# R/H ENGINE 2 CYLINDER INTAKE GASKET LEAKING
# L/H ENGINE CYLINDER ROCKER COVER GASKET LEAKING
# L/H ENGINE 4 CYLINDER AFT UPPER SUPPORT BRACKET CRACKED ON BAFFLE
# R/H ENGINE CYLINDER 3 1 ROCKER COVER GASKETS LEAKING
# 2 4 ROCKER COVERS LEAKING
# 3 ROCKER COVER GASKET LEAKING
# ON CLIMB OUT ENGINE LOST ABOUT 250 RPM
# ROCKER COVER GASKETS CYLINDER 2 4 LEAKING
# ENGINE OVER RIDE SPEED WAS 1225 RPM
# 1 ROCKER COVER LEAKING
# CYLINDER 3 EXTERNAL GASKET 1/2 GONE
# OIL COOLER LINES LACING CORD FALLLING APART
# R/H ENGINE CYLINDER 4 3 INTAKE GASKETS LEAKING
# L/H ENGINE CYLINDER 1 3 INTAKE GASKETS LEAKING
# L/H ENGINE CYLINDER 2 3 4 ROCKER COVER GASKETS LEAKING
# R/H ENGINE ALL CYLINDER ROCKER COVER GASKETS LEAKING
# CYLINDER 4 INTAKE GASKET LEAKING
# R/H ENGINE 3 CYLINDER HAS LOW COMPRESSION 54/80
# R/H ENGINE 2 3 ROCKER COVERS LEAKING
# L/H ENGINE 1 3 ROCKER COVERS LEAKING
# R/H ENGINE 4 CYLINDER AFT BAFFLE WIRE HARNESS TAB CRACKE
# 2 ROCKER COVER LEAKING
# 4 ROCKER COVER LEAKING
# 2 INTAKE GASKET LEAKING
# 1 CYLINDER MISSING A ROCKER COVER SCREW
# INTAKE GASKET CYLINDER 2 LEAKING
# ROCKER COVER GASKET CYLINDER 4 LEAKING
# CYLINDER 2 3 ROCKER COVERS LEAKING
# 3 CYLINDER EXHAUST VALVE PUSH ROD TUBE APPEARS TO BE LEAKIN
# 3 CYLINDER EXHAUST VALVE PUSH ROD TUBE APPEARS TO BE LEAKIN
# INTAKES 2 3 4 LEAKING ON R/H ENGINE
# INTAKES 2 4 LEAKING ON L/H ENGINE
# ROCKER COVERS 1 2 4 LEAKING ON L/H ENGINE
# 3 CYLINDER ON R/H ENGINE HAS LOW COMPRESSION
# 3 CYLINDER ON R/H ENGINE HAS LOW COMPRESSION
# 3 CYLINDER ON R/H ENGINE HAS LOW COMPRESSION
# 3 CYLINDER ON R/H ENGINE HAS LOW COMPRESSION
# 3 CYLINDER ON R/H ENGINE HAS LOW COMPRESSION
# 3 CYLINDER ON R/H ENGINE HAS LOW COMPRESSION
# R/H ENGINE 1 INTAKE LEAKING
# L/H ENGINE 2 INTAKE TUBE GASKET LEAKING
# A/C WOULD NOT START
# CYLINDER 2 L/H ENGINE INTAKE GASKET LEAKING
# R/H ENGINE CYLINDER 1 2 3 4 ROCKER COVERS LEAKING
# L/H ENGINE CYLINDER 1 3 4 ROCKER COVER GASKETS LEAKING
# 1 CYLINDER LOWER INTAKE CLAMPS LOOSE
# 2 3 ROCKER COVERS LEAKING
# CRACK IN AFT ENGINE BAFFLE OIL COOLER ON R/H ENGINE
# 3 INTAKE LEAKING ON R/H ENGINE
# IDLE OVERRIDE LOW
# 1 3 4 CYLINDER ROCKER COVERS LEAKING
# CYLINDER 2 ROCKER COVER GASKET LEAKING
# CYLINDER 2 ROCKER COVER GASKET LEAKING
# SPARK PLUG ACCESS HOLE ON BAFFLE CYLINDER 4 ELONGATED
# 2 ROCKER COVER LEAKING
# CYLINDER 2 INTAKE GASKET LEAKING
# 2 4 ROCKER COVER GASKETS LEAKING
# INTAKE GASKET CYLINDER 2 LEAKING
# ROCKER COVER GASKETS CYLINDER 1 2 3 LEAKING
# FRONT RUBBER BAFFLE ON ENGINE R/H SIDE RIPPED FROM MOUNTIN
# R/H BAFFLE HAS A CRACK
# CYLINDER 4 INTAKE LEAKING
# CYLINDER 3 ROCKER COVER LEAKING
# CYLINDER 1 ROCKER COVER GASKET TORN
# CYLINDER 4 INTAKE GASKET LEAKING
# CYLINDER 1 3 ROCKER COVER GASKETS LEAKING
# 4 INTAKE LEAKING ON L/H ENGINE
# 1 4 INTAKES LEAKING ON R/H ENGINE
# ALL ROCKER COVER SCREWS LOOSE
# L/H ENGINE CYLINDER 3 AFT BAFFLE CRACKED
# L/H ENGINE CYLINDER 1 3 INNER CYLINDER BAFFLE TIE ROD AFT NUT MAGNETIC INDICATOR
# CYLINDER 2 3 4 INTAKE GASKETS LEAKING ON L/H ENGINE
# CYLINDER 1 3 ROCKER COVER GASKETS LEAKING ON L/H ENGINE
# R/H ENGINE CYLINDER 1 3 ROCKER COVER GASKETS LEAKING
# CYLINDER 3 INTAKE PIPE NEEDS TO BE RESWEDGED INTO SUMP
# R/H REAR BAFFLE MOUNTING SCREW LOOSE
# 2 INTAKE TUBE GASKET LEAKING
# 1 INTAKE LEAKING
# 2 INTAKE GASKET LEAKING
# 2 3 4 ROCKER GASKETS LEAKING
# R/H SIDE BAFFLE CRACKED
# 1 ROCKER COVER LEAKING
# 2 FORWARD LOWER BAFFLE HAS CRACK
# 4 INTAKE LEAKING
# 2 INTAKE LEAKING
# 2 ROCKER COVER LEAKING
# 3 ROCKER COVER LEAKING
# CYLINDER 4 ROCKER COVER GASKET LEAKING
# 2 4 INTAKE GASKETS LEAKING
# L/H INTERCYLINDER BAFFLE LOOSE
# L/H SIDE OF ENGINE BAFFLE WIRE LOOSE
# L/H ENGINE CYLINDER 2 INTAKE GASKET LEAKING
# R/H ENGINE CYLINDER 3 INTAKE GASKET LEAKING
# L/H ENGINE R/H BACK BAFFLE CRACKED
# L/H ENGINE 2 INTAKE LEAKING
# L/H ENGINE 3 ROCKER COVER LEAKING
# ENGINE BAFFLE BEHIND ALTERNATOR CRACKED
# ROCKER COVER GASKETS 2 4 LEAKING
# R/H FORWARD BAFFLE CRACKED
# 3 ROCKER COVER LEAKING
# R/H ENGINE BAFFLE SCREW MISSING
# 4 INTAKE LEAKING ON R/H ENGINE
# FORWARD BAFFLE CHAFING ON MUFFLER SHROUD
# CYLINDER 4 INTAKE LEAKING
# 1 ROCKER COVER LEAKING
# 3 ROCKER COVER LEAKING
# 3 INTAKE GASKET LEAKING
# CYLINDER 4 ROCKER COVER GASKET LEAKING
# R/H ENGINE 4 BAFFLE SEAL TORN
# R/H ENGINE 3 INTAKE TUBE GASKET LEAKING
# R/H ENGINE 1 3 BAFFLE TIE ROD SPACER LOOSE
# CYLINDER 3 L/H ENGINE INTAKE GASKET LEAKING
# R/H ENGINE CYLINDER 2 INTAKE GASKET LEAKING
# CYLINDER 3 AFT BAFFLE I/B MOUNT RIVETS SHEARED
# L/H ENGINE CYLINDER 4 INTAKE LEAKING
# L/H ENGINE CYLINDER 2 FORWARD BAFFLE SEAL TORN
# R/H ENGINE FORWARD CYLINDER 2 BAFFLE SEAL TORN
# L/H ENGINE SNIFFLER VALVE HOSE ADEL CLAMP RUBBER WORN OUT
# L/H ENGINE CYLINDER 1 2 3 ROCKER COVERS LEAKING
# IMMEDIATELY AFTER ENGINE START HIGH PITCHED WHINE/SQUEAL/WH
# CYLINDER 4 3 ROCKER COVER GASKETS LEAKING
# R/H BACK BAFFLE BRACKET RIVET SHEARED OFF
# L/H BACK BAFFLE HAS A CRACK
# 1 INTAKE LEAKING
# ALL ROCKER COVER SCREWS LOOSE
# ADEL CLAMP TORN BY R/H ENGINE MOUNT
# RIVNUT STRIPPED OUT ON FIREWALL FOR A/F FUEL FILTER
# LEFT ENGINE N1 RPM HAS 3 TO 4 UNCOMMANDED INCREASE WHEN ENGINE
# TABS BROKEN OFF BAFFLE PLUGS L/H R/H SIDES
# ENGINE QUIT WHEN THROTTLE WAS CLOSED DURING SHUT DOWN PRIOR
# L/H ENGINE L/H BAFFLE TIE ROD PULLED THROUGH BAFFLE
# L/H ENGINE 2 INTAKE GASKET LEAKING
# BAFFLE SEAL LOOSE ON LH/ ENGINE 4 AFT BAFFLE
# BAFFLE SEAL LOOSE ON R/H ENGINE 1 SIDE BAFFLE
# 2 4 CYLINDER ROCKER COVER GASKETS LEAKING
# R/H ENGINE BURNER CAN DRAIN RIGID LINE CONTACTING BOTTOM CUTTOFF
# R/H ENGINE BURNER CAN DRAIN RIGID LINE CONTACTING BOTTOM CUTTOFF
# R/H ENGINE FORWARD BAFFLE SEAL LOOSE
# RIVETS MISSING ON ENGINE DATA PLATE
# AFTER TAKEOFF RPMS WERE FLUCTUATING ENGINE STARTED TO RU
# OIL LEAK NOTED ON FRONT ENGINE SECTION
# OIL LEAK NOTED ON FRONT ENGINE SECTION
# CYLINDER 1 INTAKE GASKET LEAKING
# CYLINDER 2 3 4 ROCKER COVERS LEAKING
# FORWARD BAFFLE CHAFING ON EXTERNAL SHROUD
# CYLINDER 4 INTAKE GASKET LEAKING
# FORWARD ENGINE BAFFLE CRACKED BEHIND ALTERNATOR
# CYLINDER 1 2 ROCKER COVER GASKETS LEAKING
# R/H REAR ENGINE BAFFLE SCREW LOOSE
# INTAKES 2 4 LEAKING ON L/H ENGINE
# INTAKE GASKET CYLINDER 2 LEAKING
# ROCKER COVER GASKET CYLINDER 2 LEAKING
# CYLINDER 4 INTAKE LEAKING
# FORWARD BAFFLE CHAFING ON MUFFLER HEAT SHROUD
# 2 ROCKER COVER GASKET LEAKING
# CYLINDER 1 GOVERNOR BAFFLE SEAL COMING OFF
# 1 INTAKE LEAKING
# ON RUN UP L/H MAGNETOS DROPPED 350 RPM
# ON RUN UP L/H MAGNETOS DROPPED 350 RPM
# ON RUN UP L/H MAGNETOS DROPPED 350 RPM
# ON RUN UP L/H MAGNETOS DROPPED 350 RPM
# CYLINDER 1 INTAKE TUBE LOOSE
# ALL 4 ROCKER COVERS HAVE LOOSE SCREWS
# CYLINDER 4 BAFFLE PLUG HOLE ENLARGED
# CYLINDER 2 ROCKER COVER GASKET LEAKING
# CYLINDER 4 INTAKE LEAKING
# CYLINDER 32 INTAKE GASKET LEAKING
# 3 CYLINDER ROCKER COVER GASKET LEAKING
# FORWARD BAFFLE CRACKED HEAT SHROUD AIR INTAKE
# CYLINDER 2 INTAKE GASKET LEAKING
# ROCKER COVER GASKET 3 LEAKING
# 3 CYLINDER AFT BAFFLE SCREW LOOSE
# FORWARD R/H ENGINE BAFFLE SEAL LOOSE
# 4 ROCKER COVER GASKET LEAKING
# OIL LINE 90 DEGREE ADEL CLAMP BRACKET BROKEN
# CYLINDER 4 ROCKER COVER GASKET NEEDS TO BE REPLACED
# CYLINDER 2 3 INTAKES LEAKING
# BOTH BAFFLE PLUGS HAVE TOO MANY TABS MISSING
# CYLINDER 2 4 ROCKER COVERS LEAKING
# CYLINDER 3 AFT BAFFLE I/B MOUNT RIVETS SHEARED
# 3 4 INTAKES LEAKING
# CYLINDER 2 INTAKE TUBE AT SUMP HAS POSSIBLE FUEL LEAK
# 4 INTAKE LEAKING
# 1 ROCKER COVER LEAKING
# ROCKER COVERS 1 2 4 LEAKING
# R/H FORWARD BAFFLE SEAL LOOSE
# 4 INTAKE LEAKING
# 4 INTAKE GASKET LEAKING
# CYLINDER 2 ROCKER COVER LEAKING
# CYLINDER 1 3 ROCKER COVER GASKETS LEAKING
# POWER AT IDLE ENGINE QUIT RESTARTED TESTED IDLE W/ FULL
# DURING FLIGHT R/H COWL FLAP WOULD NOT STAY OPEN
# R/H BAFFLE TIE ROD BROKEN
# 2 INTAKE LEAKING
# L/H ENGINE 2 INTAKE GASKET LEAKING
# 1 CYLINDER EXHAUST STACK MISSING NUT R/H
# R/H ENGINE 4 CYLINDER BAFFLE SEAL TEARING OFF
# R/H ENGINE TOP CRANKCASE HALF BOLT W/ ENGINE HOIST LOOP LEAKING
# SUPPORT FROM 4 CYLINDER AFT BAFFLE TO CRANKCASE HALF BROKEN O
# BAFFLE PLUG TANGS BROKEN OFF
# 2 INTAKE CYLINDER GASKET LEAKING
# FORWARD R/H BAFFLE SEAL LOOSE
# CYLINDER 3 INTAKE GASKET LEAKING
# R/H BAFFLE PLUG NEEDS TO BE REPLACED
# CYLINDER 4 2 INTAKE GASKETS LEAKING
# 2 INDUCTION TUBE GASKET LEAKING
# R/H FORWARD BAFFLE SEAL LOOSE
# ON ENGINE START ENGINE WAS UNUSUALLY ROUGH ATTEMPTED TO LEADING-EDGE
# ON ENGINE START ENGINE WAS UNUSUALLY ROUGH ATTEMPTED TO LEADING-EDGE
# ON ENGINE START ENGINE WAS UNUSUALLY ROUGH ATTEMPTED TO LEADING-EDGE
# ON ENGINE START ENGINE WAS UNUSUALLY ROUGH ATTEMPTED TO LEADING-EDGE
# ON ENGINE START ENGINE WAS UNUSUALLY ROUGH ATTEMPTED TO LEADING-EDGE
# ON ENGINE START ENGINE WAS UNUSUALLY ROUGH ATTEMPTED TO LEADING-EDGE
# ON ENGINE START ENGINE WAS UNUSUALLY ROUGH ATTEMPTED TO LEADING-EDGE
# R/H FORWARD BAFFLE SEAL LOOSE
# AFT BAFFLE SEAL LOOSE R/H SIDE
# CYLINDER 2 4 ROCKER COVERS LEAKING
# 1 2 3 4 ROCKER COVER GASKETS LEAKING
# CYLINDER 3 INTAKE GASKET LEAKING
# 4 INTAKE LEAKING
# 1 ROCKER COVER LEAKING
# 2 INDUCTION TUBE GASKET LEAKING
# 4 CYLINDER COMPRESSION TEST WAS 35/80
# 4 CYLINDER COMPRESSION TEST WAS 35/80
# 4 CYLINDER COMPRESSION TEST WAS 35/80
# 4 CYLINDER COMPRESSION TEST WAS 35/80
# R/H FORWARD BAFFLE SEAL LOOSE
# LEAKING INTAKE TUBE CYLINDER 4 LEAK AT ATTACH POINT TO OIL SUMP
# LEAKING INTAKE TUBE CYLINDER 4 LEAK AT ATTACH POINT TO OIL SUMP
# 4 INTAKE LEAKING
# R/H ENGINE WIRING CLAMP FORWARD I/B NOT ATTACHED
# OIL SEEP R/H ENGINE TACH GEN
# CYLINDER 2 OIL RETURN LINE WAS DISCONNECTED FITTING REMOVED
# 1 3 O/B BAFFLE TIE WORN THRU AFT BAFFLE
# 2 OIL DRAIN TUBE CHAFING ON BAFFLE
# 2 FORWARD BAFFLE CRACKED BEYOND STOP DRILL
# REAR BAFFLE BRACKET AT ENGINE CENTER BROKEN AT BOLT
# CYLINDER 2 OIL RETURN LINE WAS DISCONNECTED FITTING REMOVED
# 2 ROCKER COVER LEAKING
# R/H REAR ENGINE BAFFLE SCREW LOOSE
# 3 INTAKE LEAKING
# R/H FORWARD ENGINE BAFFLE MISSING PLUG
# 4 INTAKE LEAKING
# 1 ROCKER COVER LEAKING
# CYLINDER 2 3 4 ROCKER COVER GASKETS LEAKING
# FAILED OVERRIDE SPEED CHECK RPM DROPPED TO 800 RPM STABIL
# ROCKER COVER GASKETS 2 3 TORN
# CYLINDER 2 INTAKE GASKET LEAKING
# ENGINE RPM WAS 1700
# R/H BAFFLE SUPPORT ROD FOR CYLINDER 1 3 BROKEN
# CYLINDER 3 AFT BAFFLE HAS SHEARED RIVET
# 2 4 ROCKER COVER GASKETS LEAKING
# BAFFLE SEAL TORN FORWARD OF 2 CYLINDER ON L/H R/H ENGINES
# 3 CYLINDER RIGHT ENGINE SHOWS NO EXHAUST GAS TEMPERATURE
# 3 CYLINDER AFT BAFFLE ON L/H ENGINE CRACKED
# 4 INTAKE GASKET LEAKING
# 2 ROCKER COVER LEAKING
# CYLINDER 2 INTAKE GASKET LEAKING
# R/H ENGINE 2 INDUCTION TUBE GASKET LEAKING
# ROCKER COVERS 2 3 4 LEAKING ON R/H ENGINE
# 1 4 ROCKER COVERS LEAKING ON L/H ENGINE
# 2 INTAKE LEAKING ON L/H ENGINE
# 2 4 ROCKER COVERS LEAKING ON L/H ENGINE
# ROCKER COVERS 2 4 LEAKING ON R/H ENGINE
# 3 CYLINDER ON R/H ENGINE HAS LOW COMPRESSION
# 3 CYLINDER ON R/H ENGINE HAS LOW COMPRESSION
# 3 CYLINDER ON R/H ENGINE HAS LOW COMPRESSION
# CYLINDER 3 LEAKING INTAKE TUBE AT OIL SUMP
# CYLINDER 3 LEAKING INTAKE TUBE AT OIL SUMP
# ROCKER COVER GASKETS CYLINDER 2 3 4 LEAKING
# 2 INTAKE LEAKING
# 4 INTAKE LEAKING
# INTAKE GASKET 4 LEAKING
# FOREIGN OBJECT DAMAGE ON TOP OF ENGINE
# 1 INTAKE LEAKING
# BAFFLE SPARK PLUG ACCESS PLUG WORN
# 4 INTAKE TUBE LOOSE
# CYLINDER 2 INTAKE GASKET LEAKING
# CYLINDER 2 4 ROCKER COVER GASKETS LEAKING
# ALTERANATE AIR DOOR WORN
# CYLINDER 1 BAFFLE CRACKED
# 4 INTAKE LEAKING
# CYLINDER 2 3 ROCKER COVER GASKETS LEAKING
# ROCKER COVER GASKET CYLINDER 2 LEAKING
# R/H AFT BAFFLE CRACKED BY ENGINE MOUNT BOLT HOLE
# CENTER TOP BAFFLE BRACKET CRACKED
# 2 INTAKE LEAKING
# ALL ENGINE ROCKER COVER SCREWS LOOSE
# STARTER WOULD TURN TWICE THEN CUT OFF DURING START UP
# 4 INTAKE GASKET LEAKING
# 4 ROCKER GASKET LEAKING
# WORN BAFFLE PLUGS
# ROCKER COVER GASKETS CYLINDER 2 4 LEAKING
# 2 ROCKER COVER GASKET LEAKING
# DURING GO AROUND FROM A SIMULATED ENGINE FAILURE ENGINE RAN ROUGH
# L/H ENGINE 4 CYLINDER HAS BAD EXHAUST VALVE
# 3 INTAKE LEAKING ON R/H ENGINE
# 1 3 ROCKER COVERS LEAKING ON L/H ENGINE
# L/H ENGINE 4 CYLINDER HAS BAD EXHAUST VALVE
# L/H ENGINE 4 CYLINDER HAS BAD EXHAUST VALVE
# L/H ENGINE FIRST STAGE COMPRESSOR ROTOR HAS 1
# CYLINDER 2 TOP BAFFLE SEAL LOOSE
# INTAKE GASKET CYLINDER 3 LEAKING
# ROCKER COVER GASKET CYLINDER 3 LEAKING
# INTAKE TUBE CYLINDER 1 LEAKING AROUND OIL SUMP CONNECTION AREA
# INTAKE TUBE CYLINDER 1 LEAKING AROUND OIL SUMP CONNECTION AREA
# 4 INTAKE GASKET LEAKING
# 3 4 ROCKER GASKETS LEAKING
# ENGINE OVERSPEED TO 2730 RPM FOR 1 SECOND
# 2 ROCKER COVER GASKET LEAKING
# 2 INTAKE TUBE LEAKING AT SUMP CYLINDER
# CYLINDER 4 ROCKER COVER GASKET LEAKING
# CYLINDER 4 ROCKER COVER GASKET LEAKING
# CYLINDER 2 4 INTAKE GASKETS APPEAR TO BE LEAKING
# 4 INTAKE LEAKING
# 3 2 ROCKER COVERS LEAKING
# HIGH PITCHED SQUEALING NOISE HEARD DURING FLIGHT
# LOW POWER AVAILABLE HELO REQUIRED LMP TO HOVER
# CYLINDER 4 2 ROCKER COVER GASKETS LEAKING
# 1 CYLINDER ROCKER OIL RETURN LINE CHAFING
# 1 CYLINDER ROCKER OIL RETURN LINE CHAFING
# 2 4 ROCKER COVER GASKETS LEAKING
# BAFFLE BUTTON PLUG WORN
# 3 ROCKER COVER GASKET TORN
# CYLINDER 2 INTAKE GASKET LEAKING
# FORWARD BOTTOM ENGINE BAFFLE SEAL HAS HOLES IN IT
# CYLINDER 3 ROCKER COVER GASKET LEAKING
# 4 ROCKER COVER GASKET LEAKING
# OIL COOLER LOWER BAFFLE SEAL MISSING
# 2 ROCKER COVER LEAKING
# L/H ENGINE WILL NOT START
# CYLINDER 1 ROCKER COVER GASKET LEAKING
# 2 INTAKE LEAKING
# 1 2 ROCKER COVERS LEAKING
# ENGINE DIED AFTER LANDING
# ENGINE HAD MOMENTARY OVERSPEED TO 2770 RPM
# 2 CYLINDER ROCKER COVER SCREW MISSING
# 1 ROCKER COVER GASKET LEAKING
# INTAKE GASKET CYLINDER 2 LEAKING
# ROCKER COVER GASKET CYLINDER 2 LEAKING
# 3 INTAKE GASKET LEAKING
# 3 INTAKE LEAKING
# R/H BAFFLE SAFETY WIRE BROKEN
# L/H BAFFLE BUTTON PLUG BROKEN
# 2 INTAKE LEAKING
# CYLINDER 1 3 4 ROCKER COVERS LEAKING
# CASE HALVES LEAKING ON BOTTOM FORWARD PORTION
# 1 INTAKE LEAKING
# L/H I/B BAFFLE SPRING BRKOEN
# ROCKER COVER GASKET CYLINDER 2 LEAKING
# INTAKE GASKET CYLINDER 2 LEAKING
# CYLINDER 4 INTAKE GASKET LEAKING
# 2 4 INTAKES LEAKING ON L/H ENGINE
# R/H ENGINE CYLINDER 4 AFT BAFFLE BRACKET CRACKED
# R/H ENGINE CYLINDER 3 INTAKE GASKET LEAKING
# L/H ENGINE CYLINDER 2 ROCKER COVER LEAKING
# L/H ENGINE ROCKER COVER GASKETS CYLINDER 3 LEAKING
# R/H ENGINE CYLINDER 3 ROCKER COVER GASKET LEAKING
# 2 INDUCTION TUBE GASKET LEAKING
# PARTICLE SEPERATOR HAS GRASS IN IT
# CYLINDER 4 INTAKE LEAKING
# FORWARD LOWER ENGINE BAFFLE CRACKED
# R/H ENGINE SIDE BAFFLE CRACKED
# CYLINDER 2 ROCKER COVER GASKET LEAKING
# FORWARD BAFFLE NEAR ALTERNATOR CRACKED
# BOTH ENGINE BAFFLE BUTTONS WORN
# ALL ROCKER COVER SCREWS LOOSE 1 MISSING
# CYLINDER 4 INTAKE LEAKING
# DURING CRUISE ENGINE BECAME INCREDIBLY ROUGH ENGINE CONTIN
# DURING CRUISE ENGINE BECAME INCREDIBLY ROUGH ENGINE CONTIN
# DURING CRUISE ENGINE BECAME INCREDIBLY ROUGH ENGINE CONTIN
# 3 INTAKE LEAKING
# BOTH BAFFLE PLUGS WORN
# R/H AFT BAFFLE CRACKED
# ROCKER COVER GASKET CYLINDER 1 LEAKING
# 4 ROCKER COVER GASKET LEAKING
# 4 ROCKER COVER GASKET LEAKING
# SCREW MISSING ON 4 ROCKER COVER
# 4 INTAKE LEAKING
# L/H BAFFLE PLUG LOCK TABS MISSING
# 3 ROCKER COVER LEAKING
# 2 INTAKE LEAKING
# R/H FORWARD ENGINE BAFFLE SEAL LOOSE
# 2 INDUCTION TUBE GASKET LEAKING
# R/H REAR ENGINE BAFFLE SUPPORT BRACKET RIVETS BROKEN
# 2 4 INTAKES LEAKING
# 3 INTAKE LEAKING ON R/H ENGINE
# INTAKES 2 3 4 LEAKING ON L/H ENGINE
# LOWER L/H FORWARD BAFFLE SEAL LOOSE
# CLIMBING AFTER TAKEOFF ENGINE CHOKED BACK FIRED
# LOWER FRONT ENGINE CASE HALF SEAM LEAKING
# LOWER FRONT ENGINE CASE HALF SEAM LEAKING
# 4 INTAKE TUBE LEAKING
# 1 ROCKER COVER LEAKING
# LEFT IDLER GEAR HAS SPALLING ON FUEL PUMP CAM
# LEFT IDLER GEAR HAS SPALLING ON FUEL PUMP CAM
# CYLINDER 2 ROCKER COVER GASKET LEAKING
# 4 INTAKE LEAKING
# 2 ROCKER COVER LEAKING
# 2 INTAKE LEAKING
# 2 INTAKE LEAKING
# 1 ROCKER COVER LEAKING
# ROCKER COVER GASKETS 3 2 LEAKING
# CYLINDER 4 AFT BAFFLE CRACKED
# L/H ENGINE BAFFLE PLUG DAMAGED
# R/H 4 INTAKE GASKET LEAKING
# CYLINDER 2 3 4 ROCKER COVER GASKETS LEAKING
# CYLINDER 2 INTAKE GASKET LEAKING
# ROCKER COVER GASKET CYLINDER 4 LEAKING
# 1 3 ROCKER COVERS LEAKING
# 2 4 ROCKER COVERS LEAKING
# BOLT MISSING FROM 4 CYLINDER HEAD
# BOLT MISSING FROM 4 CYLINDER HEAD
# 2 3 INTAKE LEAKING
# 2 ROCKER COVER LEAKING
# 2 INDUCTION TUBE GASKET LEAKING
# 4 INDUCTION TUBE GASKET LEAKING
# R/H ENGINE REACHED 2770 RPM ON TAKE OFF
# 4 INTAKE GASKET LEAKING
# SCREW MISSING ON 2 ROCKER COVER
# 3 4 ROCKER COVER LEAKING
# 3 1 CYLINDER INTAKE GASKETS LEAKING
# CRACK IN FORWARD BAFFLE CENTER
# FORWARD LOWER BAFFLE SEAL LOOSE
# CYLINDER 2 INTAKE GASKET LEAKING
# ROCKER COVER GASKETS CYLINDER 1 2 LEAKING
# FORWARD L/H ENGINE BAFFLE CRACKED FROM HEAT AIR INTAKE DOWN
# 2 ROCKER COVER GASKET LEAKING
# ROCKER COVER GASKET FROM CYLINDER 2 LEAKING
# OIL COOLER HAS A GAP FROM COWLING BOX ON BOTTOM
# EXHAUST GAS TEMPERATURE  CYLINDER 1 CLAMP LOOSE
# 3 ROCKER COVER LEAKING
# 2 4 ROCKER COVER LEAKING
# 4 ROCKER COVER GASKET TORN
# 4 INTAKE LEAKING
# L/H ENGINE BAFFLE SEAL RIVETS LOOSE
# R/H REAR ENGINE BAFFLE MOUNTING SCREW MISSING BRACKET RIVE
# INTAKE GASKETS 1 3 LEAKING
# CYLINDER 4 BAFFLE PLUG TEETH BROKEN
# ROCKER COVER GASKETS ON CYLINDER 3 4 LEAKING
# 3 INTAKE GASKET LEAKING
# 1 SIDE BAFFLE CRACKED
# 3 4 ROCKER GASKETS LEAKING
# 4 INTAKE TUBE LEAKING
# 3 INTAKE LEAKING ON R/H ENGINE
# HARDWARE MISSING ON L/H ENGINE 2 CYLINDER
# INTAKES 2 4 LEAKING ON R/H ENGINE
# MUFFLER HEAT MUFF CRACKED
# FAILS MIXTURE CHECK NO RPM RISE
# INTAKE GASKETS CYLINDER 2 4 LEAKING
# 4 INTAKE GASKET LEAKING
# 2 INDUCTION TUBE GASKET LEAKING
# BOTH BAFFLE PLUGS BAD
# 3 ROCKER COVER LEAKING
# ROCKER COVER GASKET FROM CYLINDER 2 LEAKING
# 3 INDUCTION TUBE GASKET LEAKING
# R/H REAR ENGINE BAFFLE MOUNTING SCREW MISSING
# RAN SMOOTHLY AFTER ENGINE START LEAN PROCEDURE THEN RAN VER
# RAN SMOOTHLY AFTER ENGINE START LEAN PROCEDURE THEN RAN VER
# RAN SMOOTHLY AFTER ENGINE START LEAN PROCEDURE THEN RAN VER
# 3 AFT BAFFLE CRACKED
# 2 3 INTAKE GASKETS LEAKING
# R/H L/H VALVE COVERS LEAKING
# L/H ENGINE OIL COOLER TO ENGINE LIFTING EYE BRACKET BROKEN
# R/H ENGINE LIFTING EYE BOLT LEAKING OIL
# 2 INTAKE LEAKING
# R/H ENGINE 4 CYLINDER BAFFLE BRACE NEEDS TO BE REMOVED FOR CAN O
# R/H ENGINE 4 CYLINDER BAFFLE BRACE NEEDS TO BE REMOVED FOR CAN O
# AUTO RELIGHT DEFERRED
# LEFT ENGINE WOULD NOT START ATTEMPTED NORMAL FLOODED
# L/H BAFFLE PLUG DAMAGED
# CYLINDER 2 BAFFLE SCREW MISSING
# ENGINE HESITATION/ROUGHNESS 30 SECOND AFTER TAKEOFF NO FURTHER
# ALL VALVE COVERS LEAKING
# 2 4 INTAKES LEAKING
# CYLINDER 2 3 ROCKER COVERS LEAKING
# 3 INDUCTION TUBE GASKET LEAKING
# 2 4 INTAKE GASKETS LEAKING
# LEAKING INTAKE GASKET CYLINDER 2
# LEAKING ROCKER COVER GASKET CYLINDER 4
# ENGINE RPM OF 2720
# CYLINDER 3 ROCKER COVER GASKET LEAKING
# CRANKSHAFT SEAL APPEARS TO BE LEAKING
# CRANKSHAFT SEAL APPEARS TO BE LEAKING
# CRANKSHAFT SEAL APPEARS TO BE LEAKING
# CYLINDER 2 4 INTAKE GASKETS LEAKING
# CYLINDER 3 AFT BAFFLE SCREW TIGHT BUT BAFFLE LOOSE
# CYLINDER 4 INTAKE GASKET LEAKING
# ROCKER COVER GASKETS LEAKING CYLINDER 2 3
# 4 INTAKE LEAKING
# 2 4 INTAKES LEAKING
# ENGINE BAFFLE PLUGS BAD
# R/H REAR ENGINE BAFFLE MOUNT SCREW LOOSE
# L/H BAFFLE TIE BROKEN
# CYLINDER 2 3 ROCKER COVER GASKETS LEAKING
# CENTER AFT ENGINE BAFFLE CRACKED
# 4 INTAKE GASKET LEAKING
# 2 INTAKE GASKET LEAKING
# 2 CYLINDER COMPERSSION READING LOW
# 1 2 4 INTAKES LEAKING
# 4 INTAKE GASKET LEAKING
# 2 4 CYLINDER ROCKER COVER SCREWS LOOSE
# L/H BAFFLE PLUG HOLE ELONGATED
# CYLINDER 2 INTAKE GASKET LEAKING
# CYLINDER 3 ROCKER COVER GASKET LEAKING
# 2 4 ROCKER COVER GASKETS LEAKING
# 2 CYLINDER INTAKE LEAKS
# 1 CYLINDER HAS LOW COMPRESSION
# 1 CYLINDER HAS LOW COMPRESSION
# INTAKE 2 3 4 LEAKING
# ENGINE BAFFLE PLUGS DAMAGED
# 1 CYLINDER HAS LOW COMPRESSION
# 1 CYLINDER HAS LOW COMPRESSION
# 1 CYLINDER HAS LOW COMPRESSION
# CYLINDER 1 3 SIDE BAFFLE CRACKED
# CYLINDER 2 EXHAUST TUBE ELBOW TOP BOLT NEEDS TO BE RECOTTER PINN
# CYLINDER 1 ROCKER COVER GASKET LEAKING
# ROCKER COVER GASKETS CYLINDER 2 4 LEAKING
# AFT BAFFLE SUPPORT CYLINDER 3 HAS SHEARED RIVET
# BAFFLING CRACKED R/H ENGINE BY 4 CYLINDER
# CYLINDER 3 ROCKER COVER GASKET LEAKING
# L/H COOLING BAFFLE CONNECTING ROD BROKEN
# R/H CYLINDER COOLING BAFFLE CONTACTING OIL RETURN LINE
# CYLINDER 2 INTAKE GASKET LEAKING
# CYLINDER 2 4 ROCKER COVER GASKETS LEAKING
# FORWARD CENTER ENGINE BAFFLE CRACKED
# CYLINDER 2 3 4 ROCKER COVER GASKETS LEAKING
# 2 ROCKER COVER LEAKING
# HARDWARE MISSING ON R/H REAR BAFFLE
# 2 INDUCTION TUBE GASKET LEAKING
# R/H BAFFLE SEAL BY PROP GOVERNOR LOOSE
# 2 4 INTAKE LEAKING
# INTAKE GASKET CYLINDER 4 LEAKING
# INTAKE GASKETS CYLINDER 1 3 LEAKING
# ROCKER COVER GASKETS CYLINDER 3 4 1 LEAKING
# R/H AFT BAFFLING RIVETS SHEARED
# 3 CYLINDER LOWER SPARK PLUG BOSS THREADS DAMAGED
# R/H BAFFLE PLUG WORN
# L/H FORWARD BAFFLE CRACKED
# L/H FORWARD ENGINE BAFFLE CRACKED AT CORNER
# 2 INTAKE GASKET LEAKING
# 4 BOTTOM ROCKER COVER SCREW WONT TIGHTEN
# 2 3 INTAKES LEAKING ON L/H ENGINE
# 1 INTAKE TUBE DAMAGED
# 4 INTAKE LEAKING ON L/H ENGINE
# 3 INTAKE LEAKING ON L/H ENGINE ALONG W/ 2
# INTAKES 2 3 4 LEAKING
# 2 INTAKE GASKET LEAKING
# ROCKER COVER GASKET 1 LEAKING
# FORWARD LOWER ENGINE BAFFLE SEAL LOOSE
# 2 4 INTAKES ON R/H ENGINE LEAKING
# CYLINDER 2 INTAKE GASKET LEAKING
# R/H BAFFLE PLUG MISSING
# LEFT RIGHT BAFFLE PLUGS HAVE SEVERAL BROKEN FINGERS
# BAFFLE PLUG WORN
# ROCKER COVER GASKETS 2 3 LEAKING
# L/H ENGINE BAFFLE SCREW MISSING
# R/H ENGINE BAFFLE 2 4 CROSSTIE BROKEN
# R/H ENGINE 2 3 4 ROCKER BOX COVERS LEAKING
# CYLINDER 3 ROCKER COVER GASKET LEAKING
# R/H AFT COOLING BAFFLING RIVETS SHEARED
# CYLINDER 3 ROCKER COVER GASKET LEAKING
# BAFFLE PLUGS HAVE BROKEN FINGERS
# CYLINDER 2 4 ROCKER COVER GASKETS LEAKING
# 4 BAFFLE CRACKED IN FRONT OF OIL COOLER
# CYLINDER 2 3 ROCKER COVER GASKETS LEAKING
# 4 INTAKE LEAKING ON R/H ENGINE
# 2 4 INTAKES LEAKING ON L/H ENGINE
# 2 ROCKER COVER LEAKING ON R/H ENGINE
# 3 ROCKER COVER LEAKING ON L/H ENGINE
# R/H PROP SHAFT SEAL SEEPING
# R/H PROP SHAFT SEAL SEEPING
# CYLINDER 3 ROCKER COVER GASKET LEAKING
# CYLINDER 2 INTAKE GASKET LEAKING
# L/H BAFFLE PLUG MISSING TEETH
# 2 4 INTAKE GASKETS LEAKING
# 3 ROCKER COVER GASKET LEAKING
# CYLINDER 1 INTAKE GASKET ELAKING
# L/H I/B BAFFLE SPRING BROKEN
# CYLINDER 1 ROCKER COVER GASKET LEAKING
# ENGINE FAILURE WHILE HOLDING SHORT THROTTLE WAS IDLE
# CYLINDER 4 INTAKE GASKET LEAKING
# CYLINDER 4 HAS LOW COMPRESSION
# 2 INTAKE GASKET LEAKS
# 2 ROCKER COVER LEAKS
# 4 INTAKE LEAKING
# ALL ROCKER COVERS HAVE LOOSE SCREWS
# RIVET SHEARED R/H AFT BAFFLE
# RIVET SHEARED R/H AFT BAFFLE
# ROCKER COVERS 2 3 4 LEAKING
# 4 INTAKE GASKET LEAKING
# L/H 3 ROCKER COVER LEAKING
# 2 ENGINE LEFT REAR BAFFLE CRACKED INTERCYLINDER CONNECT
# 2 ROCKER GASKET LEAKING
# 1 3 BAFFLE TIE WIRE LOOSE
# 2 4 INTAKE GASKETS LEAKING
# BOLT MISSING CONNECTING UPPER ENDS OF 3 4 AFT BAFFLES
# R/H REAR ENGINE BAFFLE MOUNTING SCREW LOOSE
# CRACKED FRONT UPPER R/H SIDE ENGINE BAFFLE ON 1 CYLINDER
# 4 ROCKER GASKET LEAKING
# ON APPROACH ENGINE ROUGHNESS ABOUT 7 10 SECS ADJUSTED MAGNETIC INDICATOR
# ON APPROACH ENGINE ROUGHNESS ABOUT 7 10 SECS ADJUSTED MAGNETIC INDICATOR
# PERFORMING GROUND REF MANUAL THROTTLE WAS AT 1600 RPM THROTTL
# PERFORMING GROUND REF MANUAL THROTTLE WAS AT 1600 RPM THROTTL
# PERFORMING GROUND REF MANUAL THROTTLE WAS AT 1600 RPM THROTTL
# PERFORMING GROUND REF MANUAL THROTTLE WAS AT 1600 RPM THROTTL
# PERFORMING GROUND REF MANUAL THROTTLE WAS AT 1600 RPM THROTTL
# PERFORMING GROUND REF MANUAL THROTTLE WAS AT 1600 RPM THROTTL
# ENGINE COWL DZUS FASTENERS NEED RETAINERS
# R/H ENGINE SHUT DOWN ON LANDING WAS ABLE TO RESTART TAXI
# 2 INTAKE ON R/H ENGINE LEAKING
# R/H ENGINE 3 ROCKER COVER LEAKING
# 2 4 ROCKER COVER ON R/H ENGINE LEAKING
# L/H ENGINE 3 ROCKER COVER LEAKING
# ENGINE STARTED SEEMED TO BE RUNNING FINE SUDDENLY ENGINE
# ENGINE STARTED SEEMED TO BE RUNNING FINE SUDDENLY ENGINE
# ENGINE STARTED SEEMED TO BE RUNNING FINE SUDDENLY ENGINE
# ENGINE STARTED SEEMED TO BE RUNNING FINE SUDDENLY ENGINE
# R/H ENGINE 3 CYLINDER INTAKE GASKET LEAKING
# R/H ENGINE 4 CYLINDER INTAKE GASKET LEAKING
# 4 CYLINDER SIDE BAFFLE ON L/H ENGINE MISSING A BOLT
# L/H ENGINE R/H FORWARD BAFFLE SEAL LOOSE
# L/H ENGINE 1 CYLINDER INTAKE LEAKS
# L/H ENGINE 3 CYLINDER COMPRESSION LOW
# L/H ENGINE 3 CYLINDER COMPRESSION LOW
# L/H ENGINE 3 CYLINDER COMPRESSION LOW
# L/H ENGINE 3 CYLINDER COMPRESSION LOW
# R/H ENGINE 1 CYLINDER INTAKE GASKET LEAKING ALONG W/ 2 4
# 2 4 ROCKER COVERS LEAKING ON L/H ENGINE
# ALL 4 VALVE COVERS LEAKING ON R/H ENGINE
# LEFT BAFFLE PLUG WORN
# CRACK ON OIL COOLER FLANGE
# INTAKES 1 3 LEAKING
# CYLINDER 4 ROCKER COVER GASKET LEAKING
# CYLINDER 1 3 BOTTOM BAFFLE CRACKED TIE ROD
# 3 CYLINDER ROCKER BOX COVER SCREW MISSING
# 4 INTAKE LEAKING OIL SUMP
# 4 INTAKE LEAKING OIL SUMP
# CYLINDER 2 INTAKE GASKET LEAKING
# INTAKE GASKET CYLINDER 2 LEAKING
# ROCKER COVER GASKETS CYLINDER 2 4 LEAKING
# AFT ENGINE BAFFLE WORN FROM RUBBING
# 1 CYLINDER BAFFLE NOT BEHIND CYLINDER NUT INCORRECT INSTALL
# 2 ROCKER COVER LEAKING
# L/H ENGINE 3 INTAKE LEAKING
# R/H ENGINE 3 INTAKE LEAKING
# L/H ENGINE 3 ROCKER COVER LEAKING
# SCREW MISSING IN 3 SIDE BAFFLE
# 3 ROCKER COVER GASKET LEAKING
# 2 ROCKER COVER LEAKING
# COOLING BAFFLE ATTACHMENT BRACKET BEHIND OIL FILL TUBE
# ENGINE COOLING BAFFLE SEAL LOOSE ON TOP L/H SIDE
# COOLING BAFFLE ATTACHMENT BRACKET BEHIND OIL FILL TUBE
# 1 ROCKER GASKET SEEPING
# CYLINDER 4 ROCKER COVER GASKET LEAKING
# 1 INTAKE GASKET TORN
# 1 3 ROCKER GASKETS LEAKING
# 4 ROCKER GASKET LEAKING
# 3 PUSH ROD SEALS LEAKING
# 2 INTAKE LEAKING
# 4 ROCKER COVER LEAKING
# 1 INTAKE LEAKING AT OIL SUMP
# 4 INTAKE GASKET LEAKING
# 4 ROCKER COVER GASKET LEAKING
# 2 ROCKER COVER GASKET SEEPING
# ROCKER COVER GASKET ON CYLINDER 3 LEAKING
# CYLINDER 2 INTAKE GASKET LEAKING
# THROTTLE LINKAGE SERVO SLOPPY
# CYLINDER 1 3 SIDE BAFFLE BOLT LOOSE
# ENGINE AFT R/H GROUND STRAP NEEDS TO BE SECURED
# CYLINDER 1 3 BOTTOM BAFFLE CRACKED
# R/H ENGINE 2 4 SIDE BAFFLE SEALS TORN
# R/H ENGINE 2 4 INTAKE GASKETS LEAKING
# 2 4 INTAKE GASKETS LEAKING L/H ENGINE
# 2 3 4 ROCKER GASKETS LEAKING L/H ENGINE
# R/H ENGINE 2 3 ROCKER GASKETS LEAKING
# SCREW BEHIND OIL FILLER TUBE LOOSE
# SCREW BEHIND OIL FILLER TUBE LOOSE
# SPARK PLUG CAP LOOSE ON 3 BOTTOM SPARK PLUG
# L/H ENGINE 3 4 INTAKES LEAKING
# L/H ENGINE 3 4 ROCKER COVERS LEAKING
# R/H ENGINE CYLINDER 2 3 4 INTAKE GASKETS LEAKING
# TOOL ON TOP OF ENGINE BETWEEN CYLINDERS
# 3 CYLINDER BAFFLE MISSING SCREW ON BRACKET
# CYLINDER 2 ROCKER COVER GASKET DAMAGED
# 2 INTAKE LEAKING
# L/H ENGINE 3 BAFFLE AFT SEAL LOOSE
# 2 4 SIDE BAFFLE SEALS TORN ON R/H ENGINE
# 1 INDUCTION TUBE GASKET LEAKING
# BOTH L/H R/H BAFFLE PLUGS WORN
# BROKEN ANCHOR ASSEMBLY ON 1 CYLINDER
# 2 CYLINDER FORWARD BAFFLE CRACKED
# CYLINDER 2 INTAKE GASKET LEAKING
# 2 3 ROCKER GASKETS LEAKING
# 3 4 INTAKE GASKETS LEAKING
# R/H ENGINE 2 STACK BROKEN OFF
# INTAKE GASKET 4 LEAKING
# 2 4 ROCKER COVER GASKETS LEAKING
# SCREW MISSING ON ENGINE COOLING BAFFLE R/H SIDE NEXT TO OIL
# DURING HIGH SPEED ROLL A/C HAD STRONG VIBRATION
# 2 3 INTAKE GASKETS LEAKING
# AFTER 20 MANIFOLD PRESSURE APPLIED FULL THROTTLE STARTED
# 2 INTAKE LEAKING
# 4 2 INDUCTION TUBE GASKET LEAKING
# CYLINDER 2 3 4 INTAKE GASKETS LEAKING
# CYLINDER 2 3 4 ROCKER COVER GASKETS LEAKING
# CYLINDER 4 INTAKE GASKET LEAKING
# CYLINDER 1 WIRING HARNESS SUPPORT BRACKET BROKEN
# AIR INDUCTION ELBOW TO SERVO BOOT WEEPING FUEL
# 3 CYLINDER ROCKER GASKET SEEPING
# 2 INTAKE GASKET LEAKING
# 1 3 4 ROCKER COVERS LEAKING
# 2 INTAKE LEAKING
# 2 INDUCTION TUBE GASKET LEAKING
# 2 INTAKE LEAKING
# 2 BAFFLE PLUGS NEEDS TO BE REPLACED
# 2 SIDE BAFFLE SEAL STAPLES LOOSE
# 2 4 ROCKER GASKETS LEAKING
# ENGINE COULD NOT START
# 3 INTAKE LEAKING
# 3 ROCKER COVER LEAKING
# 4 CYLINDER COMPRESSION 15/80
# 4 CYLINDER COMPRESSION 15/80
# 4 CYLINDER COMPRESSION 15/80
# 4 CYLINDER COMPRESSION 15/80
# CYLINDER 2 INTAKE GASKET LEAKING
# COWL SHOCK MOUNT 7 DAMAGED
# R/H AFT BAFFLE BRACKET SCREW MISSING
# MISSING SCREW ON L/H ENGINE 3 BAFFLE
# 3 INTAKE LEAKING ON L/H ENGINE
# 3 4 INTAKE GASKETS LEAKING R/H ENGINE
# INTAKE GASKET TO CYLINDER 1 LEAKING
# 4 INTAKE LEAKING
# 4 ROCKER COVER LEAKING
# CYLINDER 4 ROCKER COVER GASKET LEAKING
# CYLINDER 2 INTAKE GASKET LEAKING
# CYLINDER 4 INTAKE GASKET LEAKING
# INTAKE GASKET CYLINDER 2 LEAKING
# ROCKER COVER GASKET CYLINDER 3 LEAKING
# R/H AFT BAFFLE SCREW MISSING
# CYLINDER 2 3 4 ROCKER COVER GASKET LEAKING
# 1 3 ROCKER GASKETS LEAKING
# AIR INLET TUBE DAMAGED
# WHILE MAKING RIGHT TURN CLIMBING OUT HEARD LOUD KNOCK CUTTOFF
# L/H ENGINE TAC GEN LEAKS AT SEAL
# L/H ENGINE TAC GEN LEAKS AT SEAL
# L/H ENGINE TAC GEN LEAKS AT SEAL
# 2 3 4 INTAKES LEAKING ON L/H ENGINE
# INTAKES 1 2 3 4 LEAKING ON R/H ENGINE
# L/H O/B BAFFLE SPRING BROKEN
# 1 2 ROCKER COVER GASKETS LEAKING
# 3 INTAKE LEAKING
# L/H ENGINE AFT L/H BAFFLE OIL COOLER CRACKED
# INTAKES 3 4 LEAKING ON L/H ENGINE
# L/H SIDE ENGINE 2 3 4 INTAKES LEAKING
# CRACK IN FRONT ENGINE BAFFLE L/H SIDE
# ENGINE BAFFLE SEAL TORN BOTTOM R/H CORNER
# 2 3 4 ROCKER COVER GASKETS LEAKING L/H ENGINE
# 1 3 4 ROCKER COVER GASKETS LEAKING ON R/H ENGINE
# L/H 3 INTAKE GASKET LEAKING
# R/H 2 3 INTAKE GASKETS LEAKING
# 3 ROCKER BOX COVER GASKET LEAKING
# 2 ROCKER COVER GASKET LEAKING
# BROKEN ANCHOR STANDBY ASSEMBLY ON 3 CYLINDER
# TOP ENGINE COOLING FAN BAFFLE PLUGS WORN OUT
# CYLINDER 4 INTAKE GASKET LEAKING
# 3 CYLINDER ROCKER COVER GASKET LEAKING
# INTAKE GASKETS CYLINDER 2 4 LEAKING
# ROCKER COVER GASKET CYLINDER 2 4 LEAKING
# 4 INTAKE GASKET LEAKING
# CYLINDER 1 3 4 INTAKE GASKETS LEAKING
# BROKEN ANCHOR ASSEMBLY ON 2 CYLINDER
# L/H ENGINE 4 SIDE BAFFLE MISSING A BOLT
# INTAKE 2 4 LEAKING ON R/H ENGINE
# INTAKE 1 2 3 4 LEAKING ON L/H ENGINE
# ROCKER COVERS 2 3 4 LEAKING ON R/H ENGINE
# L/H R/H AFT 4 BAFFLES HAVE CRACKS
# R/H 3 INTAKE LEAKING
# L/H 4 INTAKE GASKET LEAKING
# L/H ENGINE 1 3 BAFFLE TIE ROD WEARING ON INTERBAFFLE
# L/H 3 4 ROCKER COVER GASKETS LEAKING
# 2 CYLINDER INTAKE GASKET LEAKING
# A/C WILL NOT START
# 2 4 INTAKES LEAKING
# 2 ROCKER GASKET LEAKING
# SCREW LOOSE ON ENGINE BAFFLING
# 1 ROCKER GASKET LEAKING
# LEFT ENGINE 3 INTAKE LEAKING
# 3 INDUCTION TUBE GASKET LEAKING
# CYLINDER 3 4 ROCKER COVER GASKETS LEAKING
# CYLINDER 1 2 ROCKER COVER GASKETS LEAKING
# CYLINDER 3 ROCKER COVER GASKET LEAKING
# ENGINE BAFFLE R/H AFT NEXT TO 3 CYLINDER NEEDS TO BE SCREWED I
# CYLINDER 1 ROCKER COVER GASKET LEAKING
# CYLINDER 2 ROCKER COVER GASKET LEAKING
# OIL LEAK ON R/H ENGINE BACK BONE CASE SEAM
# L/H ENGINE L/H BAFFLE TIE ROD DAMAGED
# L/H ENGINE 1 ROCKER BOX COVER LEAKING
# OIL LEAK ON R/H ENGINE BACK BONE CASE SEAM
# 1 INTAKE GASKET LEAKS
# R/H ENGINE LEFT SIDE AFT BAFFLE CRACKED
# R/H ENGINE LEFT SIDE AFT BAFFLE CRACKED
# R/H ENGINE ALL ROCKER COVER GASKETS LEAKING
# R/H ENGINE 2 INTAKE LEAKING
# L/H ENGINE 3 ROCKER COVER LEAKING
# 4 INTAKE LEAKING
# R/H ENGINE BAFFLE PLUG MISSING
# CYLINDER 1 INTAKE GASKET LEAKING
# 2 INTAKE LEAKING
# L/H ENGINE BAFFLE PLUG MISSING
# CYLINDER 2 ROCKER COVER GASKET LEAKING
# COWL SHOCK MOUNT 1 TORN
# AT FULL POWER SMOOTHLY APPLIED ENGINES WOULD VIBRATE VIOL
# AT FULL POWER SMOOTHLY APPLIED ENGINES WOULD VIBRATE VIOL
# L/H ENGINE BAFFLE SCREW MISSING
# 2 CYLINDER INTAKE GASKET LEAKING
# ACCESSORY PAD BEHIND ALTERNATOR HAS BRACKET INSTALLED W/ NOT
# 4 INTAKE LEAKING ON L/H ENGINE
# INTAKE LEAKING ON R/H ENGINE 3
# 3 ROCKER COVER LEAKING ON L/H ENGINE
# 2 TO 4 CYLINDER BAFFLE TIE ROD BROKEN ON LEFT ENGINE
# BOLT W/ BARREL AFT R/H SIDE OF ENGINE MISSING
# R/H ENGINE 3 CYLINDER INTAKE GASKET LEAKING
# BOLT MISSING ON 4 CYLINDER BAFFLE R/H ENGINE
# ROCKER COVERS 2 3 4 LEAKING ON L/H ENGINE
# R/H ENGINE R/H FORWARD BAFFLE CRACKED
# INTAKES 2 3 4 LEAKING ON L/H ENGINE
# INTAKES 2 3 4 LEAKING ON R/H ENGINE
# BOTH ENGINES HAVE SCREWS BETWEEN CYLINDERS ON SIDE BAFFLES T
# CYLINDER 2 ROCKER COVER GASKET LEAKING
# 4 CYLINDER INTAKE GASKET LEAKING
# 3 CYLINDER ROCKER COVER GASKET LEAKING
# 2 ROCKER COVER GASKET SQUEEZED OUT
# SCREW MISSING FROM R/H AFT BAFFLE
# 4 ROCKER COVER LEAKING
# EXCEEDED PROP LIMITS 2710 RPM FOR A FEW SECONDS
# 3 ROCKER COVER LEAKS
# BAFFLE TIE ROD LOOSE ON L/H SIDE OF R/H ENGINE
# CRACK IN R/H 4 BAFFLE BRACKET
# 4 INTAKE GASKET LEAKING ON R/H ENGINE
# 3 INTAKE GASKET LEAKING ON R/H ENGINE
# 3 INTAKE GASKET ON L/H ENGINE LEAKING
# R/H ENGINE BLEED AIR DUCT CHAFING ON COWL
# 2 INTAKE GASKET LEAKING
# 2 3 ROCKER COVER GASKETS LEAKING
# 3 INTAKE GASKET LEAKING
# 4 INTAKE GASKET LEAKING
# ROCKER COVER GASKET ON CYLINDER 3 4 LEAKING
# CYLINDER 2 INTAKE LEAKING ON R/H ENGINE
# LEAKING ROCKER COVER GASKETS CYLINDER 3 4
# ENGINE AFT BAFFLE NEXT TO 3 CYLINDER HAS SHEARED RIVETS
# 2 3 4 ROCKER GASKETS LEAKING
# 1 ROCKER COVER GASKET LEAKS
# BAFFLE CRACKED BEHIND ALTERNATOR
# CYLINDER 4 3 ROCKER COVER GASKETS LEAKING
# 3 2 4 INTAKES LEAKING ON L/H ENGINE
# R/H ENGINE AFT I/B BAFFLE OIL COOLER CRACKED
# 1 3 ROCKER COVERS LEAKING ON L/H ENGINE
# 1 3 CYLINDER SIDE BAFFLES CRACKED
# AFTER ENGINE START ENGINE RAN ROUGH BUT THEN SMOKED OUT AIRWAY FACILITIES
# AFTER ENGINE START ENGINE RAN ROUGH BUT THEN SMOKED OUT AIRWAY FACILITIES
# AFTER ENGINE START ENGINE RAN ROUGH BUT THEN SMOKED OUT AIRWAY FACILITIES
# AFTER ENGINE START ENGINE RAN ROUGH BUT THEN SMOKED OUT AIRWAY FACILITIES
# ROCKER COVER GASKETS 2 4 LEAKING
# ON RUN UP FAULTY MAGNETO CHECK PROCEDURES
# LEAKING ROCKER COVER GASKETS CYLINDER 3 4
# 4 CYLINDER ROCKER COVER GASKET LEAKING
# 3 ROCKER COVER LEAKING L/H
# 3 ROCKER COVER LEAKING ON R/H ENGINE
# 2 3 INTAKES LEAKING ON L/H ENGINE
# L/H BAFFLE ROD BROKEN ON L/H ENGINE
# 3 ROCKER COVER LEAKING L/H
# 2 3 INTAKES LEAKING ON R/H ENGINE
# 3 ROCKER COVER LEAKING ON R/H ENGINE
# 2 3 INTAKE GASKETS LEAKING
# 2 4 INTAKES LEAKING
# 4 ROCKER COVER LEAKING
# 3 2 ROCKER COVER GASKETS LEAK R/H ENGINE
# 3 2 ROCKER COVER GASKETS LEAK L/H ENGINE
# L/H O/B BAFFLE TIE BROKEN
# R/H ENGINE L/H BAFFLE TIE ROD BROKEN
# R/H ENGINE 3 4 CYLINDER INTAKE GASKETS LEAKING
# R/H ENGINE 4 CYLINDER AFT BAFFLE AFT BAFFLE CORNER SUPPORT BRACKET
# 2 4 INTAKE GASKETS LEAKING
# OVERSPEED PROP 2700 RPM FOR 3 SECONDS NOTICED 2760 RPM MAX
# CLIMBED TO ALTITUDE ATTEMPTED DESCENT BACK TO ALTITUDE LEA
# R/H ENGINE 2 CYLINDER FORWARD BAFFLE MISSING A SCREW
# R/H ENGINE 3 CYLINDER ROCKER COVER GASKET LEAKING
# L/H ENGINE 3 4 CYLINDER INTAKE GASKETS LEAKING
# L/H ENGINE 2 3 4 CYLINDER ROCKER COVER GASKETS LEAKING
# BAFFLE PLUGS MISSING
# CYLINDER 2 INTAKE GASKET LEAKING
# ENGINE BAFFLE RUBBER SEAL INSECURE 2 CYLINDER
# CYLINDER 2 INTAKE GASKET LEAKING
# ENGINE AFT BAFFLE CYLINDER 3 AREA HAS SHEARED RIVETS ON SUPPORT
# R/H L/H SIDE OF FRONT BAFFLE SEAL TORN
# 1 CYLINDER SIDE BAFFLE CRACKED
# 4 INTAKE GASKET TUBE LEAKING AT SUMP
# 4 INTAKE GASKET TUBE LEAKING AT SUMP
# 1 ROCKER COVER LEAKING
# R/H AFT BAFFLE PLUG BAD
# LEFT AFT BAFFLE SCREW LOOSE BY 4 ROCKER COVER
# CRACK IN ENGINE COOLING BAFFLE AROUND LANDING LIGHT WIRE SE
# CRACK IN ENGINE COOLING BAFFLE NEXT TO R/H UPPER MOTOR MOUN
# CRACK IN ENGINE COOLING BAFFLE NEXT TO R/H UPPER MOTOR MOUN
# 3 INDUCTION TUBE GASKET LEAKING
# L/H ENGINE L/H AFT BAFFLE CRACKED SEVERAL PLACES
# L/H ENGINE L/H AFT BAFFLE CRACKED SEVERAL PLACES
# INTAKE GASKETS FROM CYLINDER 1 2 LEAKING
# CYLINDER 2 ROCKER COVER GASKET LEAKING
# INTAKE GASKET LEAKING CYLINDER 2 3
# ROCKER COVER GASKET LEAKING CYLINDER 2 3 4
# R/H ENGINE BAFFLE PLUG BAD
# R/H REAR ENGINE BAFFLE SCREW MISSING
# CYLINDER 2 1 INTAKE GASKETS LEAKING
# CYLINDER 3 AFT BAFFLE SUPPORT RIVETS SHEARED
# L/H ENGINE BAFFLE PLUG BAD
# R/H 1 3 INTAKE GASKETS LEAKING
# R/H ENGINE HAS 4 LEAKING ROCKER GASKETS
# L/H ENGINE 2 3 4 ROCKER GASKETS LEAKING
# L/H ENGINE ALL 4 INTAKE GASKETS LEAKING
# BAFFLE SEAL TORN BOTTOM LEFT SIDE
# 4 ROCKER COVER GASKET LEAKING
# 4 INTAKE ON R/H ENGINE LEAKING
# INTAKES 2 4 LEAKING ON L/H ENGINE
# ROCKER COVER 1 LEAKING ON L/H ENGINE
# 1 2 ROCKER COVERS LEAKING
# PILOT REPORTED SLIGHT FLUCTUATIONS IN R/H ENGINE DURING CRUI
# 2 ROCKER COVER GASKET LEAKING R/H ENGINE
# 2 INTAKE GASKET LEAKING R/H ENGINE
# L/H ENGINE CYLINDER 2 INTAKE GASKET LEAKING
# CRACKED BAFFLE 3 CYLINDER R/H ENGINE
# 4 INTAKE GASKET LEAKING
# FRONT BAFFLE SEALS WORN
# MAINTENANCE FLIGHT REQUIRED
# MAINTENANCE FLIGHT REQUIRED
# 2 INTAKE GASKET LEAKING
# 3 ROCKER COVER GASKET LEAKING
# BOTTOM BAFFLE CONNECTING ROD BROKEN R/H SIDE
# 4 CYLINDER ROCKER COVER LEAKS
# ENGINE PAN DRAIN LINE CLUSTER NEEDS NEW ADEL CLAMPS
# 4 INTAKE GASKET LEAKING
# 3 ROCKER COVER GASKET LEAKING
# 2 CYLINDER ROCKER COVER LEAKS
# 2 CYLINDER INTAKE GASKET LEAKING
# BAFFLE PLUGS DAMAGED
# 4 INTAKE LEAKING
# R/H AFT BAFFLE BRACKET RIVETS LOOSE
# R/H FORWARD BAFFLE CRACKED
# INTAKE GASKET CYLINDER 2 LEAKING
# ROCKER COVER GASKET CYLINDER 1 LEAKING
# L/H ENGINE 2 ROCKER COVER LEAKING
# R/H ENGINE 3 CYLINDER ROCKER COVER LEAKING
# L/H ENGINE 3 CYLINDER INTAKE GASKET LEAKING
# R/H ENGINE 2 4 INTAKE GASKETS LEAKING
# R/H ENGINE 2 4 BAFFLE TIE ROD BROKEN
# L/H ENGINE 4 CYLINDER COMPRESSION 35
# L/H ENGINE OIL COOLER MOUNTING BAFFLE CRACKED
# R/H ENGINE 2 FORWARD BAFFLE SCREW WASHER LOOSE
# L/H ENGINE 3 INDUCTION TUBE GASKET LEAKING
# L/H ENGINE 4 CYLINDER COMPRESSION 35
# L/H ENGINE 4 CYLINDER COMPRESSION 35
# L/H ENGINE 4 CYLINDER COMPRESSION 35
# 1 ROCKER COVER LEAKING
# BAFFLE CRACKED AT LOWER LEFT BOLT OF OIL COOLER
# 2 CYLINDER ROCKER COVER GASKET LEAKS
# 2 3 4 ROCKER COVER GASKETS LEAKING
# 2 INTAKE LEAKING
# 4 INTAKE GASKET LEAKING
# CYLINDER 2 INTAKE GASKET LEAKING
# CYLINDER 1 3 ROCKER COVER GASKETS LEAKING
# 2 CYLINDER ANCHOR ASSEMBLY BROKEN
# 4 INTAKE LEAKING
# 3 ROCKER COVER LEAKING
# CYLINDER 4 3 ROCKER COVER GASKETS LEAKING
# 3 4 INTAKES LEAKING ON L/H ENGINE
# 2 3 4 INTAKES LEAKING ON R/H ENGINE
# 4 ROCKER COVER LEAKING ON R/H ENGINE
# 2 3 ROCKER COVERS LEAKING ON L/H ENGINE
# L/H 2 INTAKE GASKET LEAKING
# R/H 3 INTAKE GASKET LEAKING
# L/H 2 SIDE BAFFLE SEAL TORN
# R/H 2 3 ROCKER GASKETS LEAKING
# L/H 3 4 ROCKER GASKETS LEAKING
# 3 AFT BAFFLE L/H ENGINE COWL SEAL NOT SEALING
# CYLINDER 2 L/H ENGINE INTAKE GASKET LEAKING
# R/H ENGINE CYLINDER 1 ROCKER COVER GASKET LEAKING
# ROCKER COVER GASKETS L/H ENGINE CYLINDER 2 3 4 LEAKING
# DURING RUN UP RPM WOULD NOT INCREASE PAST 1560 REGARDLESS
# DURING RUN UP RPM WOULD NOT INCREASE PAST 1560 REGARDLESS
# DURING RUN UP RPM WOULD NOT INCREASE PAST 1560 REGARDLESS
# 1 INTAKE GASKET LEAKING
# 1 FRONT BAFFLE SEAL TORN
# ALL 4 ROCKER GASKETS LEAKING
# L/H ENGINE 4 CYLINDER AFT BAFFLE CRACKED
# 4 ROCKER COVER GASKET LEAKING R/H ENGINE
# 1 INTAKE GASKET LEAKING R/H ENGINE
# 2 INTAKE GASKET LEAKING
# SIDE BAFFLE PLUG HOLES WORN TOO LARGE
# 1 4 ROCKER COVER GASKETS LEAKING
# 2 INTAKE LEAKING
# 4 ROCKER COVER LEAKING
# 4 INTAKE LEAKING
# CYLINDER 3 ROCKER COVER GASKET LEAKING
# R/H BAFFLE PLUG WORN
# 2 ROCKER COVER GASKET LEAKING
# SCREW MISSING ON R/H ENGINE BAFFLE BEHIND OIL COOLER
# 1 CYLINDER BAFFLE CRACKED
# SNIFFLE VALVES DIRTY
# 4 ROCKER COVER GASKET LEAKING 2 ROCKER COVER GASKET LEAK
# L/H ENGINE INTAKE GASKET LEAKING CYLINDER 4
# R/H ENGINE 3 CYLINDER ROCKER COVER GASKET LEAKING
# R/H 2 4 ROCKER GASKETS LEAKING
# ENGINE BAFFLE ON 4 CYLINDER RIVETS SHEARED OFF
# 4 INTAKE LEAKING
# CYLINDER 2 ROCKER COVER GASKET LEAKING
# 4 INTAKE GASKET LEAKING
# R/H BAFFLE SPRING DISCONNECTED
# L/H BAFFLE PLUG HOLE ELONGATED
# FOREIGN OBJECT DAMAGE IN ENGINE INTABLE
# WRENCH LEFT ON ENGINE BOLT
# L/H FUEL PLACARD COVERED
# INTAKE GASKET CYLINDER 2 LEAKING
# ROCKER COVER GASKET CYLINDER 3 LEAKING
# ENGINE DID NOT START
# 2 INTAKE LEAKING
# R/H 1 2 3 ROCKER GASKETS LEAKING
# R/H 2 3 4 INTAKE GASKETS LEAKING
# 2 3 4 INTAKE GASKETS LEAKING L/H ENGINE
# R/H 2 CYLINDER EXHAUST PUSH ROD SEAL LEAKING
# 1 2 3 4 ROCKER COVER GASKETS LEAKING ON L/H ENGINE
# OWNER REQUESTS ENGINE COMPRESSIONS DONE
# BOTTOM LEFT BAFFLE SEAL TORN
# BAFFLE SEAL TORN BOTTOM R/H SIDE
# CYLINDER BAFFLE CHAFING ON OIL RETURN LINE 3 CYLINDER
# SCREW MISSING ON 3 BAFFLE
# 4 CYLINDER INTAKE GASKET LEAKING ON R/H ENGINE
# LEFT ENGINE 2 INTAKE GASKET LEAKS
# L/H ENGINE 1 INTAKE GASKET LEAKS
# LEFT ENGINE 4 AFT BAFFLE REINFORCEMENT ANGLE CRACKED
# CYLINDER 3 ROCKER DRAIN LINE LOOSE
# CYLINDER 3 AFT BAFFLE SUPPORT RIVETS SHEARED
# 4 INTAKE LEAKING
# 2 INTAKE GASKET LEAKING
# 2 INDUCTION TUBE GASKET LEAKING
# L/H ENGINE 3 AFT BAFFLE CRACKED
# SCREW MISSING ON 4 BAFFLE R/H ENGINE
# INTAKE GASKET CYLINDER 2 LEAKING L/H ENGINE
# 1 ROCKER COVER GASKET LEAKING R/H ENGINE
# ENGINE COOLING BAFFLE CRACKED FRONT L/H SIDE R/H ENGINE
# L/H ENGINE CYLINDER 2 3 4 ROCKER COVER GASKETS LEAKING
# 3 2 INTAKE GASKET LEAKING R/H ENGINE
# BOTTOM OIL COOLER LINE CHAFING ON FUEL PUMP R/H ENGINE
# BAFFLE TIE ROD CHAFING INTO 3 OIL RETURN LINE R/H ENGINE
# BAFFLE TIE ROD CHAFING ON 2 4 OIL RETURN LINES R/H ENGIN
# L/H MAGNETOS ON L/H ENGINE PRODUCED CONSIDERABLE VIBRATION
# 1 CYLINDER SIDE BAFFLE CRACKED
# 3 CYLINDER L/H ENGINE INTAKE GASKET LEAKING
# L/H ENGINE 2 PRIMER LNE CLAMP NEEDS TO BE REPOSITIONED
# 3 4 ROCKER COVER GASKET LEAKING L/H ENGINE
# 4 INTAKE LEAKING
# 2 ROCKER COVER LEAKING
# 3 INDUCTION TUBE GASKET LEAKING
# 2 ROCKER COVER GASKET LEAKING
# ROCKER COVER 2 3 4 GASKETS LEAKING
# MUFFLER MISSING NUT
# ENGINE REQUIRES DISASSEMBLY INSPECTION AFTER PROP STRIKE
# ENGINE REQUIRES DISASSEMBLY INSPECTION AFTER PROP STRIKE
# ENGINE REQUIRES DISASSEMBLY INSPECTION AFTER PROP STRIKE
# ...
# CYLINDER 1 3 TIE ROD LOOSE AND AFT BAFFLE CONTACTING OIL
# 2 INTAKE LEAKING
# 1 2 INTAKES LEAKING
# 3 CYLINDER HAS LOW COMPRESSION
# 3 CYLINDER HAS LOW COMPRESSION
# 3 CYLINDER HAS LOW COMPRESSION
# 3 INTAKE LEAKING
# 3 CYLINDER INTAKE GASKET LEAKING
# SCREW MISSING IN 3 SIDE BAFFLE
# 2 INTAKE LEAKING
# R/H AFT BAFFLE BRACKET HAS SHEARED RIVET
# 1 CYLINDER INTAKE GASKET BROKEN LEAKING
# 2 4 CYLINDER ROCKER COVERS MISSING 1 SCREW EACH
# DURING RUN UP WHEN CHECKING LEFT MAGNETOS THERE WAS A 250 RPM D
# LAST LANDING COMING OFF RUNWAY ENGINE SHUT DOWN
# L/H ENGINE 3 INTAKE LEAKING
# R/H ENGINE 4 INTAKE LEAKING
# R/H ENGINE INLET SCREEN WIRE BROKEN
# ENGINE STARTED MAKING ABNORMAL SOUND IN FLIGHT ABNORMAL VIB
# FORWARD BAFFLE L/H BOTTOM RUBBING W/ MUFFLER
# 1 2 3 4 INTAKES LEAKING ON R/H ENGINE
# 2 3 INTAKES LEAKING ON L/H ENGINE
# L/H LOWER ENGINE COWL CAM LOCK MISSING LOCK WASHER
# ENGINE DIED AT IDLE DURING TAXI 3 TIMES COULD NOT START AFT
# 4 INTAKE LEAKING
# OIL PRESSURE LINE SUPPORT BRACKET/FUEL FLOW TRANSDUCER WIRE
# FUEL LINE SUPPORT BRACKET OFF 2 EXHAUST PUSH ROD TUBE MISSING
# 2 ROCKER COVER LEAKING
# 2 CYLINDER INTAKE GASKET LEAKING
# BOTH BAFFLE SPARK PLUG ACCESS HOLES DAMAGED
# 1 INTAKE LEAKING
# L/H ENGINE 4 INTAKE LEAKING
# R/H ENGINE 3 4 INTAKES LEAKING
# DURING RUN UP ENGINE SHUT DOWN RESTARTED HAD FLAMES COMI
# AFTER START UP ENGINE KEPT HESITATING EVERY 45 SECONDS
# PILOT REPORTS START ASSIST
# BAFFLE PLUG WORN
# 2 1 INTAKES LEAKING
# ENGINE COVER REMOVED FOR INSPECTION
# 2 INTAKE GASKET LEAKING
# ENGINE BAFFLE PLUG TANGS BROKEN
# L/H 4 INTAKE GASKET LEAKING
# R/H 4 INTAKE GASKET LEAKING
# 3 ROCKER COVER GASKET LEAKING ON L/H ENGINE
# R/H ENGINE 4 CYLINDER INTAKE LEAKS
# R/H ENGINE HAS CRACKED 90 BRACKET FORWARD OIL COOLER NEEDS STOP D
# MANY CRACKS ON BAFFLING 3 CYLINDER R/H ENGINE BEHIND 90 BRACKET
# L/H ENGINE BAFFLE TIE ROD WIRE HITTING BOTH O/B CLAMPS
# MANY CRACKS ON BAFFLING 3 CYLINDER R/H ENGINE BEHIND 90 BRACKET
# L/H ENGINE HAS CRACKED 90 BRACKET BY FORWARD OF OIL COOLER PAS
# 3 4 INTAKE GASKETS LEAKING
# BAFFLE PLUGS NEED TO BE REPLACED
# L/H ENGINE OVERSPEED ON TAKE OFF CLIMB 27202730 COULD H
# RIVET LOOSE ON L/H BAFFLE
# 2 4 ROCKER BOX LEAKING
# LEFT ENGINE WOULD NOT START LEFT ENGIEN COVER WAS NOT PUT O
# 4 INTAKE TUBE GASKET LEAKING
# 2 CYLINDER NEEDS NEW GASKET ON ROCKER BOX
# ON DOWN WIND HAD REDUCTION IN POWER FOLLOWED BY ROUGH VIBRA
# DURING TAXI STARTED TO SMELL HEAVY FUMES CUTTOFF WARNING CAME O
# CUTTOFF LEVEL HIGH WARNING CAME ON WHILE TAXIING
# OVERSPED PROP DURING MANUEVERS 30 RPM
# 4 INTAKE GASKET LEAKING
# TAB ON 3 CYLINDER AFT BAFFLE RIVETS SHEARED OFF
# 3 CYLINDER LOW COMPRESSION 48/80
# LOOSE RIVETS R/H FORWARD BAFFLE SEAL
# 3 CYLINDER LOW COMPRESSION 48/80
# 3 CYLINDER LOW COMPRESSION 48/80
# 3 CYLINDER LOW COMPRESSION 48/80
# L/H ENGINE 2 INTAKE LEAKS
# 4 ROCKER BOX COVER LEAKING
# 2 4 INTAKES LEAKING ON R/H ENGINE
# INTAKES 2 3 4 LEAKING ON L/H ENGINE
# 1 INTAKE LEAKING
# 4 CYLINDER COMPRESSION 45/80
# 4 CYLINDER COMPRESSION 45/80
# 4 CYLINDER COMPRESSION 45/80
# 4 CYLINDER COMPRESSION 45/80
# UNABLE TO START L/H ENGINE
# L/H ENGINE 4 INTAKE GASKET LEAKING
# R/H ENGINE 3 4 INTAKE GASKETS LEAKING
# ROCKER COVER SCREW MISSING
# EVIDENCE OF SEEPAGE 3 PUSH ROD EXHAUST TUBE
# EVIDENCE OF SEEPAGE 3 PUSH ROD EXHAUST TUBE
# 2 ROCKER COVER LEAKING
# 3 INTAKE LEAKING ON R/H ENGINE
# 3 ROCKER GASKET LEAKING
# BOTH SIDE BAFFLES NEED BAFFLE PLUG PATCHES
# 1 FRONT BAFFLE SEAL LOOSE
# 2 4 INTAKES LEAKING ON L/H ENGINE
# ROUGH ENGINE
# DURING RUN UP L/H MAGNETOS DROP OUTSIDE OF STANDARDS WAS ABLE T
# DURING START UP ENGINE STARTED BUT RAN VERY ROUGH WOULD N
# DURING START UP ENGINE STARTED BUT RAN VERY ROUGH WOULD N
# BAFFLE TIE ROD BROKEN LEFT SIDE
# OIL PRESSURE READ 100105 PSI IN TRAFFIC PATTERN
# OIL PRESSURE READ 100105 PSI IN TRAFFIC PATTERN
# OIL PRESSURE READ 100105 PSI IN TRAFFIC PATTERN
# OIL PRESSURE READ 100105 PSI IN TRAFFIC PATTERN
# ON FLIGHT L/H ALTERNATOR INDICATES ZERO
# CYLINDER 2 INTAKE GASKET LEAKING
# 3 CYLINDER EXHAUST PUSH ROD SHROUD NEEDS NEW ADEL CLAMP
# NEED BOTH PUSH ROD SHROUD TUBE SEALS
# ENGINE RAN ROUDH IDLE LOW WOULDNT GO TO FULL POWER
# ENGINE RAN ROUDH IDLE LOW WOULDNT GO TO FULL POWER
# ENGINE RAN ROUDH IDLE LOW WOULDNT GO TO FULL POWER
# R/H ENGINE 2 3 4 INTAKE GASKETS LEAKING
# L/H ENGINE 2 3 4 INTAKE GASKETS LEAKING
# R/H ENGINE 4 CYLINDER COMPRESSION 40/80
# R/H ENGINE 4 CYLINDER COMPRESSION 40/80
# R/H ENGINE 3 CYLINDER COMPRESSION 59/80
# R/H ENGINE 3 CYLINDER COMPRESSION 59/80
# R/H ENGINE 3 CYLINDER COMPRESSION 59/80
# R/H ENGINE 4 CYLINDER COMPRESSION 40/80
# L/H BAFFLE PLUG BROKEN
# DURING ENGINE START ENGINE WAS RUNNING VERY ROUGH WENT THR
# DURING ENGINE START ENGINE WAS RUNNING VERY ROUGH WENT THR
# DURING ENGINE START ENGINE WAS RUNNING VERY ROUGH WENT THR
# SNIFFLER VALVES DIRTY
# 2 INTAKE LEAKING
# FRONT CRANKSHAFT OIL PLUG LEAKING
# BAFFLE TIE ON R/H BOTTOM SIDE BROKEN
# FRONT CRANKSHAFT OIL PLUG LEAKING
# 1 INTAKE LEAKING
# 3 INTAKE GASKET LEAKING
# BAFFLE PLUGS TANGS BROKEN
# 3 INTAKE LEAKING ON R/H ENGINE
# 4 INTAKE LEAKING ON L/H ENGINE
# SNIFFLER VALVES DIRTY
# 2 INTAKE LEAKING
# ENGINE RUNNING ROUGH ON TAKEOFF CRUISE CLIMB WENT THROUGH
# COMPRESSOR WASH REQUIRED
# COMPRESSOR WASH REQUIRED
# ENGINE STARTED NORMAL IDLED NORMAL BUT WHEN BROUGHT UP TO
# MISSING HARDWARE ON R/H BAFFLE MUFFLER
# 4 INTAKE TUBE LEAKING SUMP
# 4 INTAKE TUBE LEAKING SUMP
# L/H ENGINE 3 INTAKE LEAKING
# R/H ENGINE 3 ROCKER BOX COVER GASKET LEAKING
# CYLINDER 2 SUSPECTED OIL LEAK AT BASE
# CYLINDER 2 SUSPECTED OIL LEAK AT BASE
# MULTIPLE ZIP TIES ON ENGINE MOUNT
# DURING PREFLIGHT FOUND OIL LEAKING OUT FROM L/H SIDE OF ENGINE
# 2 CYLINDER INTAKE TUBE BOLT BROKEN
# SPARK PLUG BAFFLE PLUGS MISSING
# 1 CYLINDER CRACKED
# 4 INTAKE LEAKING
# INTAKE 4 LEAKING ON R/H ENGINE
# INTAKES 2 3 4 LEAKING ON L/H ENGINE
# AFTER LANDING BROUGHT POWER TO IDLE RPM GOT AS LOW AS 530
# CYLINDER 3 OR 4 HAS A STUCK EXHAUST VALVE
# CYLINDER 3 OR 4 HAS A STUCK EXHAUST VALVE
# CYLINDER 3 OR 4 HAS A STUCK EXHAUST VALVE
# 3 INTAKE TUBE GASKET LEAKING
# 1 3 ROCKER BOX COVER GASKETS LEAKING
# ACCESSORY HOUSING/VACUUM ADAPTER GASKET LEAKING
# AIRCRAFT IN GRAFTON FLAMES ON START UP BURNED/SOOTED COWL
# R/H ENGINE 3 INTAKE LEAKING
# L/H ENGINE 3 INTAKE LEAKING
# R/H ENGINE 3 ROCKER COVER LEAKING
# 2 INTAKE LEAKING
# BAFFLE BY CASE SPLIT CRACKED
# CYLINDER 3 INTAKE GASKET LEAKING
# LOWER BOLT O/B FOR OIL COOLER FLANGE LOOSE CRACKED
# R/H ENGINE CYLINDER 3 INTAKE GASKET LEAKING
# LONG BAFFLE TIE ROD CRACKED
# ENGINE VERY ROUGH AFTER START DOES NOT RUN AT IDLE
# ENGINE VERY ROUGH AFTER START DOES NOT RUN AT IDLE
# ENGINE VERY ROUGH AFTER START DOES NOT RUN AT IDLE
# ENGINE VERY ROUGH AFTER START DOES NOT RUN AT IDLE
# ENGINE VERY ROUGH AFTER START DOES NOT RUN AT IDLE
# PILOT REQUIRES START ASSIST
# MANUFACTURER REQUESTED CONNECTING ROD EXCHANGE
# MANUFACTURER REQUESTED CONNECTING ROD EXCHANGE
# MANUFACTURER REQUESTED CONNECTING ROD EXCHANGE
# MANUFACTURER REQUESTED CONNECTING ROD EXCHANGE
# MANUFACTURER REQUESTED CONNECTING ROD EXCHANGE
# 3 EX 4 IN 4 EX PUSH ROD TIPS GALLED ROCKER ARMS
# 3 EX 4 IN 4 EX PUSH ROD TIPS GALLED ROCKER ARMS
# ENGINE RUNS ROUGH ON RUN UP
# ENGINE RUNS ROUGH ON RUN UP
# 2 INTAKE LEAKING
# ENGINE WOULD SPUTTER WHEN GOING FROM IDLE TO FULL THROTTLE
# ROUGH RUNNING ENGINE IN FLIGHT PARTIAL POWER LOSS LITTLE T
# ROUGH RUNNING ENGINE IN FLIGHT PARTIAL POWER LOSS LITTLE T
# ROUGH RUNNING ENGINE IN FLIGHT PARTIAL POWER LOSS LITTLE T
# ROUGH RUNNING ENGINE IN FLIGHT PARTIAL POWER LOSS LITTLE T
# ROUGH RUNNING ENGINE IN FLIGHT PARTIAL POWER LOSS LITTLE T
# 4 CYLINDER RUNS COLD ENGINE SHAKES VIOLENTLY
# 4 CYLINDER RUNS COLD ENGINE SHAKES VIOLENTLY
# R/H GOVERNOR STILL LEAKING
# NUT MISSING ON CYLINDER 3 AFT BAFFLE MOUNT
# R/H CARBURETOR HEAT SHROUD HAS A BROKEN TAB
# 2 4 INTAKE GASKETS LEAKING L/H ENGINE
# 1 2 4 ROCKER COVER GASKETS LEAKING L/H ENGINE
# ROUGHNESS ON R/H ENGINE SUSPECT CARBURETOR ICE BUT CARBURETOR HEAT DID
# 2 4 INTAKES LEAKING
# IMMEDIATELY AFTER ENGINE START HAD ENGINE ROUGHNESS
# RIGHT ENGINE DIPSTICK TUBE SAFETY LOOSE
# RIGHT ENGINE CYLINDER 3 ROCKER COVER GASKET LEAKING
# HIGH FREQUENCY VIBRATION FELT WHILE RUNNING UP AT 2000 RPM
# HIGH FREQUENCY VIBRATION FELT WHILE RUNNING UP AT 2000 RPM
# HIGH FREQUENCY VIBRATION FELT WHILE RUNNING UP AT 2000 RPM
# HIGH FREQUENCY VIBRATION FELT WHILE RUNNING UP AT 2000 RPM
# HIGH FREQUENCY VIBRATION FELT WHILE RUNNING UP AT 2000 RPM
# HIGH FREQUENCY VIBRATION FELT WHILE RUNNING UP AT 2000 RPM
# HIGH FREQUENCY VIBRATION FELT WHILE RUNNING UP AT 2000 RPM
# HIGH FREQUENCY VIBRATION FELT WHILE RUNNING UP AT 2000 RPM
# 3 INTAKE GASKET LEAKING
# L/H FORWARD BAFFLE SEAL LOOSE
# 4 OIL RETURN LINE HOSE CLAMP LOOSE
# L/H 2 FRONT BAFFLE HAS 2 WORN SEALS
# R/H ENGINE 3 INTAKE GASKET LEAKING
# L/H ENGINE ALL 4 INTAKE GASKETS LEAKING
# SMALL AMOUNT OF METAL FOUND IN R/H ENGINE OIL FILTER
# R/H AFT ENGINE BAFFLE MOUNTING SCREW LOOSE
# 3 INTAKE LEAKING ON L/H ENGINE
# 2 4 CYLINDER INTAKE GASKETS LEAKING
# 4 INTAKE LEAKING
# L/H ENGINE 4 INTAKE LEAKING
# 3 INTAKE GASKET LEAKING
# 1 CYLINDER FORWARD BAFFLE SEAL HAS COME LOOSE
# 1 CYLINDER INTAKE GASKET LEAKING
# 2 3 4 CYLINDER ROCKER COVER GASKETS LEAKING
# 3 INTAKE LEAKING ON R/H ENGINE
# R/H ENGINE 3 4 INTAKE GASKETS LEAKING
# 3 ROCKERS PUSH RODS SCORED 2 IN 2 EX 3 EX
# L/H ENGINE 4 CYLINDER CRACKED FOUND ON COMPRESSION TEST
# L/H ENGINE 4 CYLINDER CRACKED FOUND ON COMPRESSION TEST
# L/H ENGINE 4 CYLINDER CRACKED FOUND ON COMPRESSION TEST
# 1 3 4 INTAKE GASKETS LEAKING
# 2 INTAKE LEAKING
# CYLINDER 1 3 ROCKER DRAIN LINES LEAKING
# ENGINE CHANGE REQUIRED
# ENGINE CHANGE REQUIRED
# ENGINE CHANGE REQUIRED
# ENGINE CHANGE REQUIRED
# BAFFLE TIE ROD CHAFING ON 4 OIL RETURN LINE
# CRANKSHAFT FRONT SEAL NEEDS TO BE REPLACED
# 1 4 ROCKER BOX GASKET NEEDS TO BE REPLACED
# CRANKSHAFT FRONT SEAL NEEDS TO BE REPLACED
# CRACKS ON ENGINE BAFFLE AFT OF 3 CYLINDER
# UPON ENGINE START NOTICED ENGINE WAS RUNNING EXTREMELY ROUG
# 1 CYLINDER COMPRESSION LOW
# 1 CYLINDER COMPRESSION LOW
# 3 AFT BAFFLE TAB LOOSE
# WRENCH ON CYLINDER 1
# CYLINDER 4 INTAKE GASKETS LEAKING
# INLET SCREEN COWL PANEL RUBBER UNSECURE L/H ENGINE
# L/H ENGNIE O/B BULKHEAD HAS CRACK BY ATTACH HOLES FOR LOWER
# INTAKES 2 3 LEAKING ON R/H ENGINE
# INTAKES 2 3 4 LEAKING ON L/H ENGINE
# 2 4 INTAKES LEAKING
# SCREW BEHIND DIPSTICK TUBE LOOSE FOR BAFFLE
# 1 INTAKE LEAKING
# LOWER ROCKER BOX SCREWS LOOSE ON CYLINDER 1 3
# ON ENGINE START UP ENGINE MADE LOUD GRINDING NOISE THAT DIRECTION INDICATOR
# 2 INTAKE LEAKING
# CYLINDER 3 INTAKE GASKET LEAKING
# 4 INTAKE LEAKING
# SCREW FOUND ON GROUND DURING PAD CHECK THAT WAS NOT THERE DURI
# AUDIBLE RPM LOSS ENGINE ROUGHNESS WHILE LEVELING IN DOWN W
# AIR BOX ELBOW HAS CRACK
# BAFFLE ABOVE CYLINDER 1 CRACKED
# L/H ENGINE 4 INTAKE LEAKING
# R/H ENGINE CARBURETOR AIR BOX LOOSE
# 1 INTAKE LEAKING
# 4 INTAKE LEAKING
# SCREW MISSING ON AFT R/H BAFFLE
# BAFFLE SCREW BY OIL TUBE LOOSE
# BLACK FORWARD SEAL WEAR SPOTS FROM INTAKE
# FAULTY MAGNETOS ON RUN UP RAN FAULTY MAGNETOS CHECK LIST 2 TIMES W/ SOME
# ALTERNATE AIR BOX BUSHINGS WORN
# 1 ROCKER BOX GASKET LEAKING
# 3 4 INTAKES LEAKING
# 2 3 INTAKES LEAKING ON R/H ENGINE
# ALL 4 INTAKES LEAKING ON L/H ENGINE
# LOW COMPRESSION ON CYLINDER 2 L/H ENGINE
# INTAKE GASKETS 3 4 CYLINDER LEAK
# RPM HIT 2720 DURING FLIGHT
# 1 INTAKE GASKET LEAKING
# R/H SIDE BAFFLING MISSING HARDWARE
# L/H ENGINE CYLINDER 4 INTAKE LEAKING
# L/H ENGINE CYLINDER 1 PRIMER LINE CHAFING ON INTAKE TUBE
# FOREIGN OBJECT DAMAGE 2 CYLINDER
# FOREIGN OBJECT DAMAGE ON SIDE BATTERY CASE ZIP TIE TAPED TO SIDE
# R/H REAR ENGINE BAFFLE LOOSE
# HARDWARE MISSING FROM AFT R/H BAFFLE
# NEED TO ADJUST MIXTURE 150 RISE SHUT DOWN
# ALL CYLINDER ROCKER COVERS SCREWS LOOSE
# 3 ROCKER COVER GASKET LEAKING ON L/H ENGINE
# 4 CYLINDER INTAKE GASKET LEAKING
# 3 INTAKE LEAKING
# 2 INTAKE LEAKING
# 2 INTAKE LEAKING
# BAFFLE SEALS ON 1 4 CYLINDERS NEED TO BE SECURED
# 1 4 INTAKE LEAKING ON L/H ENGINE
# REMOVE SERVICEABLE ENGINE ASSEMBLY TO PREPARE FOR TRANSPORT FOR
# PROP STRIKE/SUDDEN STOPPAGE
# PROP STRIKE/SUDDEN STOPPAGE
# R/H ENGINE 2 ROCKER COVER GASKET LEAKING
# SCREW MISSING FROM L/H FORWARD BAFFLE ON R/H ENGINE
# ROCKER COVERS 1 2 3 LEAKING ON L/H ENGINE
# R/H ENGINE 3 4 CYLINDERS INTAKE GASKETS LEAKING
# NOTICED AN ABNORMAL TICKING OR VIBRATION NOISE FROM ENGINE B
# OVERSPEED ENGINE BY 20 RPM FOR NO MORE THAN 10 SECONDS
# BAFFLE PLUGS NEED TO BE REPLACED
# 1 3 INTAKE GASKETS LEAKING
# 2 3 INTAKE LEAKING
# LOW COMPRESSION ON CYLINDER 3 55
# LOW COMPRESSION ON CYLINDER 3 55
# ENGINE BACK FIRED DURING START FLAME CAME OUT ENGINE
# 3 INTAKE GASKET LEAKING
# BAFFLE CRACKED ON 1 CYLILNDER
# LOW COMPRESSION ON CYLINDER 1
# BAFFLE ABOVE CYLINDER 1 CRACKED
# 3 ROCKER COVER GASKET LEAKING
# 1 3 ROCKER COVERS LEAKING
# ALL ROCKER DRAIN LINES SLIGHTLY LOOSE
# 1 SDIE FRONT BAFFLE SEALS LOOSE
# R/H ENGINE 2 3 4 INTAKES LEAKING
# 2 4 CYLINDER BAFFLE TIE ROD BOLT BROKEN
# BOLT FOR ALTERNATOR SUPPORT NEEDS SAFETY WIRE
# R/H ENGINE RAN ROUGH IN CLIMB CRUISE SHUT OFF L/H MAGNETOS ON
# SCREW BEHIND OIL DIPSTICK TUBE LOOSE
# L/H UPPER BAFFLE LOOSE ABOVE 2 CYLINDER
# WORN SPOTS ON FORWARD LOWER BAFFLE SEAL ABOVE INTAKE
# PAINT UNDER GROUND WIRE STRAP ON ENGINE
# INNER BAFFLE TIE SPRING BROKEN L/H SIDE
# 3 4 CYLINDER ROCKER COVER GASKETS LEAK
# 3 INTAKE LEAKING
# COMPRESSION LOW 2 CYLINDER
# COMPRESSION LOW 2 CYLINDER
# COMPRESSION LOW 2 CYLINDER
# SCREW BEHIND OIL TUBE FILTER LOOSE
# ROD CHANGE PER LYCOMING
# 4 CYLINDER PUSH ROD TUBE WASHER CORRODED
# ROD CHANGE PER LYCOMING
# ROD CHANGE PER LYCOMING
# ROD CHANGE PER LYCOMING
# AIR BOX GASKET REPLACEMENT
# L/H ENGINE 2 4 INTAKES LEAKING
# R/H ENGINE 4 INTAKE LEAKING AND 3 INTAKE
# INTAKE 3 LEAKING
# BAFFLE SCREW MISSING ON 3 CYLINDER BAFFLE
# CYLINDER 1 2 4 INTAKE GASKETS LEAKING
# 3 INTAKE LEAKS
# GROUNDING POINTS ON ENGINE FIREWALL LOOSE
# FOUND ENGINE BAFFLES CRACKED
# FOUND ENGINE BAFFLES CRACKED
# FOUND ENGINE BAFFLES CRACKED
# CRACKED FIN ON 4 CYLINDER BETWEEN TOP SPARK PLUG HOLE IN
# CRACKED FIN ON 4 CYLINDER BETWEEN TOP SPARK PLUG HOLE IN
# BOTH BAFFLE PLUGS WORN
# 1 INTAKE GASKET LEAKING
# 3 EXHAUST SIDE PUSH ROD ROCKER SCORED
# 2 CYLINDER CRACKED
# 3 EXHAUST SIDE PUSH ROD ROCKER SCORED
# 2 CYLINDER CRACKED
# 2 CYLINDER CRACKED
# 3 INTAKE LEAKING ON R/H ENGINE
# INTAKES 2 3 4 LEAKING ON L/H ENGINE
# L/H ENGINE 4 BAFFLE CRACKED
# R/H ENGINE 1 INTAKE TUBE GASKET LEAKING
# 3 EXHAUST PUSH ROD ROCKER SCORED
# INTAKES 2 4 LEAKING ON R/H ENGINE
# 4 EXHAUST PUSH ROD ROCKER ARM SCORED
# R/H ENGINE 3 CYLINDER CRACKED BY LOWER SPARK PLUG
# R/H ENGINE 3 CYLINDER CRACKED BY LOWER SPARK PLUG
# R/H ENGINE 3 CYLINDER CRACKED BY LOWER SPARK PLUG
# R/H ENGINE 3 CYLINDER CRACKED BY LOWER SPARK PLUG
# 1 3 ROCKER COVERS LEAKING
# DURING SHUT DOWN CHECKLIST WHEN PUT THROTTLE IDLE ENGINE S
# DURING SHUT DOWN CHECKLIST WHEN PUT THROTTLE IDLE ENGINE S
# DURING SHUT DOWN CHECKLIST WHEN PUT THROTTLE IDLE ENGINE S
# 2 INTAKE GASKET LEAKING
# ENGINE OVERSPEED 2750 AT PEAK
# R/H ENGINE 3 CYLINDER INTAKE GASKET LEAKING
# L/H ENGINE 3 4 CYLINDER INTAKE GASKETS LEAKING
# 4 INTAKE LEAKING
# L/H ENGINE BAFFLE PLUG TABS BROKEN
# BAFFLE SCREW BEHIND OIL TUBE LOOSE
# BAFFLE SEAL ABOVE ENGINE INTAKE HAS WORN SPOTS
# R/H REAR ENGINE BAFFLE SCREWS LOOSE
# 3 ROCKER COVER LEAKING ON R/H ENGINE
# L/H ENGINE 1 CYLINDER CRACKED
# L/H ENGINE 1 CYLINDER CRACKED
# L/H ENGINE 1 CYLINDER CRACKED
# R/H ENGINE 2 CYLINDER PUSH ROD END ROCKER SCORED
# R/H ENGINE 1 CYLINDER EXHAUST ROCKER WORN ON SHAFT
# R/H ENGINE 3 CYLINDER EXHAUST ROCKER WORN ON SHAFT
# RIGHT ENGINE LEFT MAGNETOS DROPPED 200
# R/H REAR BAFFLE MISSING GROMMET
# BAFFLE PLUGS WORN
# 4 INTAKE GASKET LEAKING
# 2 INTAKE LEAKING
# 3 4 ROCKER COVERS LEAKING
# 1 CYLINDER INTAKE BOLTS LOOSE
# BOTH BAFFLE PLUGS IN NEED OF REPLACEMENT
# ENGINE FORWARD LOWER BLACK SEAL HAS WORN SPOTS ABOVE AIR INTAKE
# RIVET LOOSE AT BAFFLE AFT CENTER
# 4 COMPRESSION 20/80
# 4 COMPRESSION 20/80
# 4 COMPRESSION 20/80
# 3 INTAKE GASKET LEAKING
# 3 INTAKE GASKET LEAKING
# 3 AFT BAFFLE HAS A BROKEN BRACKET BEHIND OIL FILLER TUBE
# L/H ENGINE 2 4 INTAKE GASKETS LEAKING
# 3 CYLINDER INTAKE TUBE NEEDS NEW GASKETS
# 3 CYLINDER INTAKE TUBE NEEDS NEW GASKETS
# 2 CYLINDER INTAKE LEAKING
# 2 INTAKE LEAKING
# BAFFLE PLUG DAMAGED
# BAFFLE PLUGS WORN
# 2 INTAKE LEAKING
# SCREW MISSING FROM 3 AFT BAFFLE
# 4 INTAKE GASKET LEAKING
# HARDWARE MISSING 3 BAFFLE
# CRACK ON 4 CYLINDER AFT BAFFLE
# BAFFLE PLUGS WORN
# CYLINDER HEAD TEMPERATURE FLUCTUATING
# 2 INTAKE LEAKING
# L/H FORWARD ENGINE BAFFLE CRACKED
# DURING RUN UP 2 CYLINDER WAS COLD ENGINE SHOCK VIOLENTLY ENGINE
# DURING RUN UP 2 CYLINDER WAS COLD ENGINE SHOCK VIOLENTLY ENGINE
# SAFETY DEPARTMENT WAS NOTIFIED OF POSSIBLE ENGINE OVERSPEED
# 6169

# %%
df['final_processed_problem'] = problem_list

# %% [markdown]
# reduced clusters from 3595 to 3386 -> merged 209 duplicate rows

# %% [markdown]
# still some abbreviations are present like CYLS and THR

# %% [markdown]
# # Final Preprocessing

# %%
processed_df.head()
# Out:
#                                    processed_problem  \
# 0           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 1           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 2           [ENGINE, IDLE, OVERRIDE, KILLED, ENGINE]
# 3  [HAD, ENGINE, CHOKE, BRIEFLY, LOSE, POWER, ON,...
# 4  [2, 4, CYLINDER, ROCKER, COVER, GASKETS, LEAKING]
#
#                                     processed_action  \
# 0  [TRIED, TO, ADJUST, IDLE, SEVERAL, TIMES, WOUL...
# 1                   [REMOVED, REPLACED, FUEL, SERVO]
# 2  [A/C, WAS, RUN, UP, SET, IDLE, SPEED, MIXTURE,...
# 3  [PERFORMED, ENGINE, RUN, UP, FOUND, CYLINDER, ...
# 4                       [REMOVED, REPLACED, GASKETS]
#
#                                  lemmatized_problems
# 0             [engine, IDLE, OVERRIDE, kill, engine]
# 1             [engine, IDLE, OVERRIDE, kill, engine]
# 2             [engine, IDLE, OVERRIDE, kill, engine]
# 3  [have, ENGINE, CHOKE, BRIEFLY, LOSE, POWER, ON...
# 4  [2, 4, cylinder, ROCKER, COVER, GASKETS, leaking]

# %% [markdown]
# ### Basic model : cosine similarity

# %%
# convert all list of words to sentences

df['processed_problem'] = df['processed_problem'].apply(lambda x: ' '.join(x))
df['processed_action'] = df['processed_action'].apply(lambda x: ' '.join(x))

# %%
df.head()
# Out:
#     IDENT                                            PROBLEM  \
# 0  100001                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 1  100002                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 2  100003                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 3  100004  HAD ENGINE CHOKE & BRIEFLY LOSE POWER ON DEPAR...
# 4  100005       #2 & 4 CYL ROCKER COVER GASKETS ARE LEAKING.
#
#                                               ACTION  \
# 0  TRIED TO ADJUST IDLE SEVERAL TIMES, WOULDN'T A...
# 1                      REMOVED & REPLACED FUEL SERVO
# 2  A/C WAS RUN UP, SET IDLE SPEED, MIXTURE OK, NO...
# 3  PERFORMED ENGINE RUN UP, FOUND CYL 2 LOWER PLU...
# 4                        REMOVED & REPLACED GASKETS.
#
#                                    processed_problem  \
# 0                 ENGINE IDLE OVERRIDE KILLED ENGINE
# 1                 ENGINE IDLE OVERRIDE KILLED ENGINE
# 2                 ENGINE IDLE OVERRIDE KILLED ENGINE
# 3  HAD ENGINE CHOKE BRIEFLY LOSE POWER ON DEPARTU...
# 4          2 4 CYLINDER ROCKER COVER GASKETS LEAKING
#
#                                     processed_action  \
# 0  TRIED TO ADJUST IDLE SEVERAL TIMES WOULDNT ADJUST
# 1                        REMOVED REPLACED FUEL SERVO
# 2  A/C WAS RUN UP SET IDLE SPEED MIXTURE OK NO LE...
# 3  PERFORMED ENGINE RUN UP FOUND CYLINDER 2 LOWER...
# 4                           REMOVED REPLACED GASKETS
#
#                              final_processed_problem
# 0                 ENGINE IDLE OVERRIDE KILLED ENGINE
# 1                 ENGINE IDLE OVERRIDE KILLED ENGINE
# 2                 ENGINE IDLE OVERRIDE KILLED ENGINE
# 3  HAD ENGINE CHOKE BRIEFLY LOSE POWER ON DEPARTU...
# 4          2 4 CYLINDER ROCKER COVER GASKETS LEAKING

# %%
# lowercase
df['processed_problem'] = df['processed_problem'].apply(lambda x: x.lower())
df['processed_action'] = df['processed_action'].apply(lambda x: x.lower())

# %%
df.head()
# Out:
#     IDENT                                            PROBLEM  \
# 0  100001                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 1  100002                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 2  100003                ENGINE IDLE OVERRIDE KILLED ENGINE.
# 3  100004  HAD ENGINE CHOKE & BRIEFLY LOSE POWER ON DEPAR...
# 4  100005       #2 & 4 CYL ROCKER COVER GASKETS ARE LEAKING.
#
#                                               ACTION  \
# 0  TRIED TO ADJUST IDLE SEVERAL TIMES, WOULDN'T A...
# 1                      REMOVED & REPLACED FUEL SERVO
# 2  A/C WAS RUN UP, SET IDLE SPEED, MIXTURE OK, NO...
# 3  PERFORMED ENGINE RUN UP, FOUND CYL 2 LOWER PLU...
# 4                        REMOVED & REPLACED GASKETS.
#
#                                    processed_problem  \
# 0                 engine idle override killed engine
# 1                 engine idle override killed engine
# 2                 engine idle override killed engine
# 3  had engine choke briefly lose power on departu...
# 4          2 4 cylinder rocker cover gaskets leaking
#
#                                     processed_action  \
# 0  tried to adjust idle several times wouldnt adjust
# 1                        removed replaced fuel servo
# 2  a/c was run up set idle speed mixture ok no le...
# 3  performed engine run up found cylinder 2 lower...
# 4                           removed replaced gaskets
#
#                              final_processed_problem
# 0                 ENGINE IDLE OVERRIDE KILLED ENGINE
# 1                 ENGINE IDLE OVERRIDE KILLED ENGINE
# 2                 ENGINE IDLE OVERRIDE KILLED ENGINE
# 3  HAD ENGINE CHOKE BRIEFLY LOSE POWER ON DEPARTU...
# 4          2 4 CYLINDER ROCKER COVER GASKETS LEAKING

# %%
processed_df['processed_problem'] = df['processed_problem']
processed_df['processed_action'] = df['processed_action']
processed_df.head(10)
# Out:
#                                    processed_problem  \
# 0                 engine idle override killed engine
# 1                 engine idle override killed engine
# 2                 engine idle override killed engine
# 3  had engine choke briefly lose power on departu...
# 4          2 4 cylinder rocker cover gaskets leaking
# 5         rocker box cover screws loose all cylinder
# 6      induction tube hose clamps loose all cylinder
# 7                                   3 intake leaking
# 8                                   2 intake leaking
# 9                             4 rocker cover leaking
#
#                                     processed_action  \
# 0  tried to adjust idle several times wouldnt adjust
# 1                        removed replaced fuel servo
# 2  a/c was run up set idle speed mixture ok no le...
# 3  performed engine run up found cylinder 2 lower...
# 4                           removed replaced gaskets
# 5                                   tightened screws
# 6                              tightened hose clamps
# 7                            removed replaced gasket
# 8                   removed replaced 2 intake gasket
# 9             removed replaced 4 rocker cover gasket
#
#                                  lemmatized_problems
# 0             [engine, IDLE, OVERRIDE, kill, engine]
# 1             [engine, IDLE, OVERRIDE, kill, engine]
# 2             [engine, IDLE, OVERRIDE, kill, engine]
# 3  [have, ENGINE, CHOKE, BRIEFLY, LOSE, POWER, ON...
# 4  [2, 4, cylinder, ROCKER, COVER, GASKETS, leaking]
# 5  [ROCKER, BOX, COVER, SCREWS, LOOSE, all, cylin...
# 6  [INDUCTION, TUBE, HOSE, CLAMPS, LOOSE, all, cy...
# 7                               [3, intake, leaking]
# 8                               [2, INTAKE, leaking]
# 9                        [4, rocker, COVER, leaking]

# %%
processed_df.drop(['lemmatized_problems'], axis=1, inplace=True)

# %%
processed_df.head()
# Out:
#                                    processed_problem  \
# 0                 engine idle override killed engine
# 1                 engine idle override killed engine
# 2                 engine idle override killed engine
# 3  had engine choke briefly lose power on departu...
# 4          2 4 cylinder rocker cover gaskets leaking
#
#                                     processed_action
# 0  tried to adjust idle several times wouldnt adjust
# 1                        removed replaced fuel servo
# 2  a/c was run up set idle speed mixture ok no le...
# 3  performed engine run up found cylinder 2 lower...
# 4                           removed replaced gaskets

# %%
processed_df.to_csv('processed_aviation_dataset.csv')
